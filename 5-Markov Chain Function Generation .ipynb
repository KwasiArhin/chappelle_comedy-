# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, in later project using RNN's or LSTM's may prove to be more fruitful in generating a better text generator.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# Generating text based on each special.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                             transcript  \
# age_spin             This is Dave. He tells dirty jokes for a livin...
# deep_texas           [Morgan Freeman] He’s in the trance. He isn’t ...
# equanimity           “Equanimity” was shot in Washington, D.C., and...
# killin_softly        Wooo! Ya’ll gone make me lose my mind. Up in h...
# stick_stones         Sticks & Stones is Dave Chappelle’s fifth Netf...
# the_bird_revelation  Recorded at the Comedy Store in Los Angeles in...
# worth                Why’d you pick San Francisco to shoot your spe...
#
#                                   titles
# age_spin                        age_spin
# deep_texas                    deep_texas
# equanimity                    equanimity
# killin_softly              killin_softly
# stick_stones                stick_stones
# the_bird_revelation  the_bird_revelation
# worth                              worth

# %%
# Extracting each special 
chapelle_text = data.transcript.loc['stick_stones']
chapelle_text[:200]
# Out:
# 'Sticks & Stones is Dave Chappelle’s fifth Netflix special.\nIn the promotional trailer Morgan Freeman narrates as Chappelle swaggers across a salt flat in leather pants, aviator shades and a remarkably'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
chapelle_dict = markov_chain(chapelle_text)
chapelle_dict
# Out:
# {'Sticks': ['&', '&'],
#  '&': ['Stones', 'Stones'],
#  'Stones': ['is', 'streamed'],
#  'is': ['Dave',
#   'Dave.',
#   'this?',
#   'the',
#   '45',
#   'perfect.',
#   'my',
#   'my',
#   'I’m',
#   'the',
#   'the',
#   'awkward',
#   'to',
#   'different.',
#   'very',
#   'an',
#   'the',
#   'the',
#   'damn',
#   'precisely',
#   'Atlanta.',
#   'many',
#   'the',
#   'it…',
#   'it',
#   'we',
#   'that',
#   'this,',
#   'gay.',
#   'the',
#   'it’s',
#   'not',
#   'that,',
#   'how',
#   'killing',
#   'not',
#   'serious.”',
#   'the',
#   'the',
#   'shame',
#   'masturbating',
#   'your',
#   'theirs.',
#   'their',
#   'fair.',
#   'an',
#   'duck.”',
#   'school',
#   'training',
#   'terrifying.',
#   'real',
#   'looking',
#   'raising',
#   'that',
#   'a',
#   'African',
#   'your',
#   'incumbent',
#   'a',
#   'an',
#   'a',
#   'this',
#   'in',
#   'buckshot.',
#   'a',
#   'not',
#   'it?',
#   'your',
#   'an',
#   'black,',
#   'that',
#   'carrying',
#   'the',
#   'funnier',
#   'MAGA',
#   'that',
#   'the',
#   'a',
#   'my',
#   'when',
#   'on',
#   'protected'],
#  'Dave': ['Chappelle’s', 'get', 'Chappelle', 'Chappelle'],
#  'Chappelle’s': ['fifth', 'Show.', 'Show,'],
#  'fifth': ['Netflix'],
#  'Netflix': ['special.\nIn'],
#  'special.\nIn': ['the'],
#  'the': ['promotional',
#   'fuck',
#   'way',
#   'bar',
#   'whole',
#   'greatest',
#   'world…',
#   'way',
#   'hood',
#   'motherfucker',
#   'best',
#   'country.',
#   'hood.',
#   'manager?',
#   'whole',
#   'point',
#   'story.',
#   'story',
#   'outside,',
#   'fuck’s',
#   'first',
#   'Founding',
#   'Constitution',
#   'next',
#   'audience',
#   'time,',
#   'worst',
#   'worst',
#   'anus.',
#   'documentary',
#   'statement.',
#   'streets',
#   'time?”',
#   'people',
#   'King',
#   'rest',
#   'next',
#   'weekend?”',
#   'limit!”',
#   'first',
#   'kid',
#   'shit,',
#   'documentary',
#   'documentary.',
#   'fuck',
#   'documentary',
#   'DJ',
#   'media',
#   'sex',
#   'transcripts.',
#   'girl’s',
#   'best',
#   'fuck',
#   'tape',
#   'best…',
#   'tape.”',
#   'Oscars.',
#   'Oscars?',
#   'odds,',
#   'most',
#   'job',
#   '80th',
#   'house,',
#   'gay',
#   'shit',
#   'first',
#   'Academy',
#   'mistake',
#   'same',
#   'department',
#   'time.',
#   'word…',
#   'lady',
#   'department.',
#   'sketches',
#   'word…',
#   'word',
#   'word',
#   'time',
#   'hard',
#   'truth.',
#   'alphabet',
#   'alphabet',
#   'letters,',
#   'T’s.',
#   'T’s',
#   'time.',
#   'same',
#   'middle',
#   'G’s',
#   'G’s.',
#   'G’s',
#   'car.',
#   'G’s',
#   'passenger',
#   'L’s.',
#   'L’s,',
#   'G’s.',
#   'G’s',
#   'only',
#   'tension',
#   'L’s',
#   'G’s',
#   'B’s',
#   'backseat.',
#   'L’s',
#   'G’s',
#   'B’s',
#   'L’s',
#   'G’s.',
#   'back',
#   'B’s,',
#   'way',
#   'backseat',
#   'window…',
#   'T’s.',
#   'car',
#   'T’s,',
#   'T’s.',
#   'T’s’',
#   'car',
#   'T’s',
#   'trip',
#   'T’s',
#   'T’s',
#   'back',
#   'fuck',
#   'window',
#   'next',
#   'restroom.”',
#   'fuck',
#   'Q’s',
#   'road.',
#   'freeway.',
#   'window.',
#   'back.',
#   'B’s',
#   'T’s.',
#   'wrong',
#   'rest',
#   'NBA,',
#   'WNBA',
#   'NBA',
#   'fuck',
#   'way',
#   'story.',
#   'door',
#   'threat?',
#   'least',
#   'Earth',
#   'police',
#   'police',
#   'other',
#   'phone.”',
#   'police',
#   'fuck',
#   'opposite',
#   'most',
#   'fuck',
#   'right',
#   'baby,',
#   'fuck',
#   'road.',
#   'table',
#   'f…',
#   'joke?',
#   'house,',
#   'subject.',
#   'fuck?”',
#   'truth.',
#   'stupidest',
#   'shooter,',
#   'other',
#   'back…',
#   'parents',
#   'shooter.',
#   'chances',
#   'rest',
#   'question',
#   'only',
#   'law.',
#   'word',
#   'nightclub',
#   'other',
#   'alley,',
#   'shit',
#   'crack',
#   'news',
#   'nation',
#   'white',
#   'black',
#   'scourge',
#   'teeth.',
#   'gun.',
#   'porch,',
#   'fuck',
#   'guy',
#   'gun',
#   'guy',
#   'counter,',
#   'counter.',
#   'fuck?',
#   'shell',
#   'barrel',
#   'gun,',
#   'face',
#   'deer',
#   'one',
#   'deer',
#   'strength',
#   'formula',
#   'gun,',
#   'top',
#   'gun.',
#   'door',
#   'kitchen',
#   'change',
#   'door.',
#   'shotgun.',
#   'change.',
#   'end',
#   'ground',
#   'heavy',
#   'cycle.',
#   'dumbest',
#   'best',
#   'victim…',
#   'victim',
#   'street',
#   'shadows,',
#   'night.',
#   'time',
#   'news,',
#   'gay',
#   'African',
#   'street',
#   'fuck?',
#   'police,',
#   'police.',
#   'house',
#   'men',
#   'fuck',
#   'audience.',
#   'jokes',
#   'headline.',
#   'Chicago',
#   'motherfuckers',
#   'funniest',
#   'only',
#   'same.',
#   'thermostat',
#   'house.',
#   'heat',
#   'floor,',
#   'middle',
#   'dance?”',
#   'fuck?',
#   'dance',
#   'change',
#   'money',
#   'dance',
#   'door,',
#   'time.',
#   'only',
#   'Matrix',
#   'footage',
#   'go,',
#   'buildin’',
#   'ceilin’',
#   'window',
#   'window',
#   'pool,',
#   'cameras',
#   'snakes',
#   'fakes',
#   'breaks',
#   'times,',
#   'sky,',
#   'way',
#   'way,',
#   'way',
#   'way',
#   'lot',
#   'world,',
#   'way…',
#   'red,',
#   'black,',
#   'green,',
#   'crossroad,'],
#  'promotional': ['trailer'],
#  'trailer': ['Morgan'],
#  'Morgan': ['Freeman', 'Freeman.'],
#  'Freeman': ['narrates'],
#  'narrates': ['as'],
#  'as': ['Chappelle',
#   'a',
#   'a',
#   'he',
#   'good',
#   'anybody',
#   'I',
#   'parents,',
#   'soon',
#   'I',
#   'bad',
#   'they',
#   'it',
#   'shit,',
#   'soon',
#   'he',
#   'long',
#   'I'],
#  'Chappelle': ['swaggers', 'to', 'Says', 'is.”'],
#  'swaggers': ['across'],
#  'across': ['a', 'my'],
#  'a': ['salt',
#   'remarkably',
#   'living.',
#   'high',
#   'luxury',
#   'nigga',
#   'full',
#   'woman',
#   'street',
#   'referee,',
#   'great',
#   'perfect',
#   'pool.',
#   'little',
#   'little',
#   'celebrity.',
#   'long',
#   'victim',
#   'free',
#   'pedophile.',
#   'goddamn',
#   'bettin’',
#   'couple',
#   'show',
#   'friend',
#   'documentary',
#   'very',
#   'lot',
#   'press',
#   'transcript',
#   'sex',
#   'thing?',
#   'thing?',
#   'lot',
#   'long',
#   'dollhouse',
#   'lot',
#   'fucking',
#   'dollhouse',
#   'department',
#   'mistake.',
#   'sketch…',
#   'nice',
#   'good',
#   'question.',
#   'nigger',
#   'babysitter',
#   'weird-timed',
#   'restroom',
#   'hitchhiker',
#   'person',
#   'fucking',
#   'woman,',
#   'game?',
#   'fucking',
#   'lot',
#   'very',
#   'guy',
#   'fuck',
#   'dick,',
#   'physician…',
#   'man',
#   'mass',
#   '$12,000',
#   'hug,',
#   'nigga',
#   'school',
#   'famous',
#   'lot',
#   'zigzag',
#   'parent,',
#   'white',
#   'white',
#   'walk',
#   'lot',
#   'lot',
#   'fuckin’',
#   'legal',
#   'trash',
#   'woman.',
#   'crisis.',
#   'real',
#   'health',
#   '12-gauge',
#   'farm',
#   'white',
#   'rifle',
#   'bitch?',
#   'bitch.',
#   'rural',
#   'slave',
#   'gun.',
#   '12-gauge',
#   'gun',
#   'picture',
#   'picture',
#   'man.”',
#   'motherfucker',
#   'motherfucker,',
#   'motherfucker',
#   'hole',
#   'goddamn',
#   'box,',
#   'picture',
#   'white',
#   'shotgun,',
#   'formula',
#   '12-gauge',
#   'heroin-addicted',
#   'test.',
#   'rational',
#   'heroin',
#   'friend',
#   'kitchen',
#   'very',
#   'show',
#   'racist',
#   'crazy',
#   'rope',
#   'police',
#   'second.',
#   'fucking',
#   'rope',
#   'show',
#   'little',
#   'little',
#   'journalist',
#   'group',
#   'poor',
#   'poor',
#   'poor',
#   'cold',
#   'mentality.”',
#   'mentality',
#   'big',
#   'chance.',
#   'long',
#   'villa',
#   'Grammy',
#   'Monday',
#   'body',
#   'ticket',
#   'bomb?',
#   'bomb?',
#   'key,'],
#  'salt': ['flat'],
#  'flat': ['in'],
#  'in': ['leather',
#   'a',
#   'France.',
#   'high',
#   'the',
#   'law',
#   'love.',
#   'your',
#   'love.',
#   'law',
#   'law',
#   'DC',
#   'D.C.',
#   'that',
#   'your',
#   'my',
#   'my',
#   'this',
#   'their',
#   'an',
#   'Detroit.',
#   'my',
#   'it?”',
#   'my',
#   'the',
#   'the',
#   'Chicago',
#   'a',
#   'the',
#   'my',
#   'my',
#   'the',
#   'all',
#   'the',
#   'America',
#   'my',
#   'it.',
#   'your',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'booty',
#   'the',
#   'the',
#   'this',
#   'and',
#   'the',
#   'this',
#   'the',
#   'the',
#   'my',
#   'a',
#   'that',
#   'his',
#   'their',
#   'Atlanta?',
#   'fact,',
#   'this',
#   'a',
#   'Virginia',
#   'life',
#   'a',
#   'there',
#   'here',
#   'the',
#   'school?',
#   'your',
#   'Ohio.',
#   'my',
#   'Dayton,',
#   'the',
#   'there,',
#   'a',
#   'the',
#   'a',
#   'a',
#   'bed',
#   'the',
#   'their',
#   'the',
#   'a',
#   'Chicago',
#   'Hollywood.',
#   'arms.',
#   'Chicago',
#   'Chicago?',
#   '1850?',
#   'on',
#   'the',
#   'the',
#   'a',
#   'you.',
#   'the',
#   'front',
#   'the',
#   'the',
#   'my',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the'],
#  'leather': ['pants,'],
#  'pants,': ['aviator'],
#  'aviator': ['shades'],
#  'shades': ['and'],
#  'and': ['a',
#   'they',
#   'I',
#   'sadly,',
#   'that',
#   'then,',
#   'he',
#   'well',
#   'finish',
#   'I',
#   'I',
#   'this',
#   'a',
#   'then',
#   'she',
#   'he',
#   'this',
#   'read',
#   'he',
#   'then',
#   'Sciences',
#   'said,',
#   'apologized',
#   'Practices.',
#   'cannot',
#   'Practices.',
#   'was',
#   'what',
#   'unspoken',
#   'them',
#   'them',
#   'the',
#   'I',
#   'you',
#   'answer',
#   'he’s',
#   'he',
#   'oppression,',
#   'you',
#   'the',
#   'the',
#   'the',
#   'sit',
#   'the',
#   'I',
#   'I',
#   'now',
#   'they',
#   'they',
#   'I',
#   'dinner',
#   'he',
#   'ran',
#   'I',
#   'she',
#   'her,',
#   'wants',
#   'run',
#   'don’t',
#   'learning',
#   'meet',
#   'that',
#   'I',
#   'no',
#   'I',
#   'I',
#   'sped',
#   'I',
#   'sweaty,',
#   'black,',
#   'I',
#   'I',
#   'shallow',
#   'he',
#   'shook',
#   'then',
#   'I’m',
#   'suddenly,',
#   'was',
#   'homophobic',
#   'he',
#   'beat',
#   'ran',
#   'Instagram',
#   'all',
#   'say,',
#   'homophobic,',
#   'where',
#   'I’m',
#   'I',
#   'a',
#   'it',
#   'he',
#   'meet',
#   'good',
#   'power',
#   'skate',
#   'the'],
#  'remarkably': ['long'],
#  'long': ['t-shirt.', 'gander', 'time', 'line', 'as'],
#  't-shirt.': ['[Morgan'],
#  '[Morgan': ['Freeman]'],
#  'Freeman]': ['This'],
#  'This': ['is',
#   'nigga',
#   'motherfucker’s',
#   'man',
#   'motherfucker',
#   'is',
#   'is',
#   'is',
#   'kid',
#   'guy,',
#   'guy',
#   'nigga',
#   'motherfucker',
#   'is',
#   'is',
#   'nigga',
#   'is',
#   'is',
#   'shit’s',
#   'is',
#   'nigga’s',
#   'shit',
#   'is',
#   'opioid',
#   'is',
#   'was',
#   'nigga’s',
#   'shit',
#   'is',
#   'how',
#   'is'],
#  'Dave.': ['He'],
#  'He': ['tells',
#   'was',
#   'didn’t',
#   'married',
#   'was',
#   'said',
#   'was',
#   'was',
#   'was',
#   'didn’t',
#   'said,',
#   'had',
#   'said,',
#   'said,',
#   'said,',
#   'goes,',
#   'lets',
#   'pops',
#   'was',
#   'said',
#   'said',
#   'told',
#   'was',
#   'Wants',
#   'didn’t',
#   'just',
#   'said,',
#   'said,',
#   'said,',
#   'said,'],
#  'tells': ['jokes', 'me,', 'you', 'me,'],
#  'jokes': ['for', 'about', 'in'],
#  'for': ['a',
#   'Christmas,',
#   'late',
#   'years,',
#   'ten',
#   'four',
#   'the',
#   'TV.”',
#   'TV.”',
#   'an',
#   'six',
#   'themselves.',
#   'the',
#   'you',
#   'four',
#   'sure',
#   'T’s.',
#   'my',
#   'the',
#   'this.',
#   'the',
#   'abortion.',
#   'it,',
#   'a',
#   'yourselves.',
#   'you,',
#   'some',
#   'sure…',
#   'a',
#   'five',
#   'that',
#   'the',
#   'everybody.',
#   'Jussie”',
#   'some',
#   'not',
#   'the',
#   'the',
#   'a',
#   'me,',
#   'sure',
#   'me.',
#   'me,',
#   'imitation'],
#  'living.': ['Hopefully'],
#  'Hopefully': ['he'],
#  'he': ['makes',
#   'got',
#   'was',
#   'met',
#   'was',
#   'was',
#   'told',
#   'should',
#   'stares',
#   'did',
#   'did',
#   'is',
#   'did',
#   'said',
#   'does',
#   'mentioned',
#   'told',
#   'told',
#   'did',
#   'got',
#   'said…',
#   'said.',
#   'said',
#   'would',
#   'went',
#   'made',
#   'went',
#   'come',
#   'stay',
#   'have',
#   'will',
#   'died',
#   'said,',
#   'came',
#   'is',
#   'was',
#   'got',
#   'had',
#   'was',
#   'got',
#   'just…',
#   'goes',
#   'goes,',
#   'lived?',
#   'picked',
#   'was',
#   'got',
#   'became',
#   'was',
#   'is',
#   'said,',
#   'could',
#   'said,'],
#  'makes': ['people', 'more', 'sense', 'you'],
#  'people': ['laugh,',
#   'running',
#   'of',
#   'in',
#   'I’ve',
#   'that',
#   'are',
#   'in',
#   'love,',
#   'so',
#   'are',
#   'talk?',
#   'never',
#   'because',
#   'ever'],
#  'laugh,': ['but'],
#  'but': ['these',
#   'it’s',
#   'it’s',
#   'that',
#   'I',
#   'we’ll',
#   'I',
#   'I',
#   'I',
#   'I',
#   'you',
#   'everyone',
#   'everyone',
#   'I’m',
#   'he',
#   'you',
#   'I',
#   'I',
#   'in',
#   'I',
#   'penetrating',
#   'this',
#   'I'],
#  'these': ['days',
#   'things.',
#   'motherfuckers.',
#   'kids.',
#   'are',
#   'Oscars.”',
#   'motherfuckers',
#   'niggas.',
#   'jokes,',
#   'people',
#   'roads.',
#   'roads.',
#   'jokes.',
#   'threads,',
#   'kids',
#   'drills,',
#   'white',
#   'heroin-addicted',
#   'details',
#   'are'],
#  'days': ['it’s'],
#  'it’s': ['a',
#   'gotta',
#   '1999',
#   'not',
#   'good.',
#   'Michael',
#   'too',
#   'just',
#   'that',
#   'not',
#   'you…',
#   'really',
#   'okay.',
#   'a',
#   'slugs',
#   'not',
#   'like',
#   'wildly',
#   'your'],
#  'high': ['stakes', 'school', 'school?'],
#  'stakes': ['game.'],
#  'game.': ['Hmm,', 'It’s'],
#  'Hmm,': ['how'],
#  'how': ['did',
#   'did',
#   'gross',
#   'good',
#   'was',
#   'hard',
#   'I',
#   'white',
#   'I',
#   'they',
#   'my',
#   'is',
#   'they',
#   'divided',
#   'the',
#   'white',
#   'much',
#   'cold',
#   'are',
#   'poor',
#   'it'],
#  'did': ['we',
#   'Dave',
#   'she',
#   'it.',
#   'do',
#   'anything',
#   'that',
#   'that',
#   'not',
#   'anything',
#   'it.',
#   'anything',
#   'they',
#   'you',
#   'it,'],
#  'we': ['get',
#   'must',
#   'get',
#   'were',
#   'made',
#   'built',
#   'can',
#   'doing?',
#   'sat',
#   'just',
#   'weren’t',
#   'didn’t',
#   'supposed',
#   'know,',
#   'know',
#   'do',
#   'should',
#   'have',
#   'were',
#   'were',
#   'understood',
#   'even',
#   'alive,'],
#  'get': ['here,',
#   'here?',
#   'married.',
#   'back',
#   'some',
#   'into',
#   'is',
#   'everybody',
#   'around,',
#   'you',
#   'where',
#   'any',
#   'in',
#   'in',
#   'worse,',
#   'pregnant.',
#   'that',
#   'shot,',
#   'enough',
#   'up',
#   'mugged,',
#   'out',
#   'in.”',
#   'a',
#   'out',
#   'the',
#   'inside.'],
#  'here,': ['I', 'then', 'but', 'baby.'],
#  'I': ['wonder?',
#   'don’t',
#   'mean,',
#   'know?',
#   'guess',
#   'was',
#   'wrote',
#   'woke',
#   'didn’t',
#   'knew',
#   'remember',
#   'told',
#   'said,',
#   'just',
#   'was',
#   'go',
#   'even',
#   'have',
#   'thought',
#   'like',
#   'only',
#   'like',
#   'want',
#   'find',
#   'don’t',
#   'find',
#   'find',
#   'don’t',
#   'felt',
#   'don’t',
#   'gotta',
#   'don’t',
#   'do',
#   'am',
#   'mean?',
#   'don’t',
#   'mean?',
#   'mean?',
#   'mean,',
#   'know',
#   'know',
#   'don’t',
#   'don’t',
#   'was…',
#   'mean,',
#   'was',
#   'was',
#   'went',
#   'just',
#   'did',
#   'talk.',
#   'would',
#   'wasn’t',
#   'cannot',
#   'didn’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'got',
#   'love',
#   'mean.',
#   'say.',
#   'say,',
#   'don’t',
#   'did',
#   'remember',
#   'was',
#   'don’t',
#   'know',
#   'mean.',
#   'don’t',
#   'got',
#   'gotta',
#   'quit.”',
#   'understand',
#   'was',
#   'made',
#   'didn’t',
#   'had',
#   'had',
#   'don’t',
#   'like',
#   'go,',
#   'here?”',
#   'didn’t',
#   'did',
#   'didn’t',
#   'said,',
#   'was',
#   'wanna',
#   'can',
#   'can’t',
#   'said,',
#   'didn’t',
#   'say',
#   'mean.',
#   'don’t',
#   'have',
#   'love',
#   'got',
#   'got',
#   'got',
#   'don’t',
#   'can’t',
#   'don’t',
#   'just',
#   'was',
#   'don’t',
#   'just',
#   'mean?',
#   'mean?',
#   'don’t',
#   'just',
#   'was',
#   'need',
#   'don’t',
#   'don’t',
#   'know',
#   'really',
#   'feel',
#   'didn’t',
#   'think',
#   'was…',
#   'was',
#   'had',
#   'feel',
#   'watch',
#   'mean?',
#   'mean?',
#   'just…',
#   'got',
#   'said',
#   'got',
#   'told',
#   'said',
#   'dare',
#   'am…',
#   'am',
#   'think',
#   'said',
#   'was',
#   'told',
#   'told',
#   'know',
#   'think',
#   'get',
#   'don’t',
#   'don’t',
#   'believe',
#   'believe',
#   'also',
#   'can',
#   'mean,',
#   'can’t',
#   'don’t',
#   'came',
#   'had',
#   'got',
#   'stiffed',
#   'don’t',
#   'never',
#   'was',
#   'told',
#   'hate',
#   'mean?',
#   'don’t',
#   'mean?',
#   'tried',
#   'never',
#   'was',
#   'had',
#   'didn’t',
#   'talk',
#   'hated',
#   'did,',
#   'don’t',
#   'know',
#   'hate',
#   'can’t',
#   'have',
#   'don’t',
#   'feel',
#   'need',
#   'live.',
#   'live',
#   'don’t',
#   'mean,',
#   'didn’t',
#   'was',
#   'was',
#   'was',
#   'had',
#   'didn’t',
#   'was',
#   'figured',
#   'open',
#   'screamed.',
#   'realized',
#   'need',
#   'was',
#   'see',
#   'don’t',
#   'feel',
#   'even',
#   'don’t',
#   'bought',
#   'didn’t',
#   'was',
#   'see',
#   'said,',
#   'was',
#   'was',
#   'ended',
#   'was',
#   'ran',
#   'was',
#   'was',
#   'mean?',
#   'ran',
#   'looked',
#   'was',
#   'looked',
#   'said,',
#   'need…',
#   'need',
#   'didn’t',
#   'said,',
#   'said,',
#   'said,',
#   'thought',
#   'was',
#   'didn’t',
#   'was',
#   'pull',
#   'hear',
#   'go,',
#   'get',
#   'say,',
#   'gotta',
#   'rack',
#   'gotta',
#   'miscalculated.',
#   'notice',
#   'got',
#   'repeat',
#   'know',
#   'would',
#   'was',
#   'figured,',
#   'figured',
#   'went',
#   'was',
#   'didn’t',
#   'said.',
#   'thought',
#   'read',
#   'said,',
#   'made',
#   'probably',
#   'see',
#   'make',
#   'was',
#   'know',
#   'know',
#   'wasn’t',
#   'please',
#   'don’t',
#   'said',
#   'didn’t',
#   'said',
#   'said,',
#   'hope',
#   'said,',
#   'was',
#   'said,',
#   'go',
#   'want',
#   'said,',
#   'don’t',
#   'was',
#   'found',
#   'will',
#   'get',
#   'just',
#   'was',
#   'did.',
#   'showed',
#   'will',
#   'fuckin’',
#   'think',
#   'ever',
#   'got',
#   'got…',
#   'don’t',
#   'don’t',
#   'just',
#   'got'],
#  'wonder?': ['I'],
#  'don’t': ['mean',
#   'know,',
#   'know',
#   'care',
#   'be',
#   'watch',
#   'want',
#   'believe',
#   'think',
#   'believe',
#   'believe',
#   'know',
#   'know',
#   'know',
#   'tell',
#   'hang',
#   'think',
#   'know',
#   'blame',
#   'apologize',
#   'know',
#   'want',
#   'blame',
#   'want',
#   'know',
#   'like',
#   'even',
#   'know',
#   'really',
#   'know',
#   'care–',
#   'care',
#   'care',
#   'want',
#   'make',
#   'try',
#   'know',
#   'see',
#   'want',
#   'know',
#   'believe',
#   'care',
#   'talk',
#   'even',
#   'know,',
#   'think',
#   'have',
#   'have',
#   'conversate',
#   'compromise,'],
#  'mean': ['that', 'to'],
#  'that': ['metaphorically,',
#   'Anthony',
#   'show',
#   'job',
#   'was',
#   'bitch',
#   'bitch',
#   'night',
#   'he',
#   'spirit,',
#   'I’m',
#   'I',
#   'Constitution,',
#   'documentary…',
#   'I’m',
#   'shit?',
#   'was',
#   'Michael',
#   'shit.',
#   'right',
#   'guy',
#   'shit.”',
#   'shit.',
#   'shit.',
#   'I',
#   'they',
#   'shit?',
#   'they',
#   'R.',
#   'crazy?',
#   'this',
#   'only',
#   'if',
#   'he’d',
#   'child’s',
#   'sound',
#   'they',
#   'community,',
#   'tells',
#   'had',
#   'runs',
#   'you',
#   'I',
#   'I’m',
#   'no',
#   'took',
#   'shit',
#   'car.',
#   'much.',
#   'breaks',
#   'the',
#   'the',
#   'car',
#   'they',
#   'guy',
#   'a',
#   'face.',
#   'face.',
#   'terrible',
#   'just',
#   'you',
#   'he',
#   'they',
#   'right.',
#   'is',
#   'shit',
#   'smell',
#   'chicken',
#   'I’d',
#   'joke.”',
#   'face',
#   'they',
#   'before.',
#   'drill.',
#   'one',
#   'if',
#   'it’s',
#   'might…”',
#   'always',
#   'is',
#   'a',
#   'knows',
#   'even',
#   'to',
#   'as',
#   'a',
#   'box',
#   'there’s',
#   'when',
#   'box',
#   'there',
#   'if',
#   'you’re',
#   'I',
#   'change.',
#   'should',
#   'his',
#   'nigga,',
#   'French',
#   'the',
#   'we',
#   'this',
#   'faggot',
#   'sound',
#   'faggot',
#   'I',
#   'shit',
#   'nigga',
#   'there',
#   'motherfucker…',
#   'headline,',
#   'very',
#   'actually',
#   'I',
#   'I',
#   'the',
#   'a',
#   'very',
#   'I',
#   'feels',
#   'was',
#   'I'],
#  'metaphorically,': ['I’m'],
#  'I’m': ['really',
#   'just',
#   'trying',
#   'gonna',
#   'gonna',
#   'not',
#   'gonna',
#   'trying',
#   'doing',
#   'gonna',
#   'goddamn',
#   'begging',
#   'gonna',
#   'not',
#   'starting',
#   'not',
#   'fucking,',
#   'a',
#   'gonna',
#   'pretty',
#   'sitting',
#   'going',
#   'working',
#   'cool.”',
#   'gonna',
#   'like,',
#   'not',
#   'sure',
#   'paraphrasing,',
#   'not',
#   'not',
#   'telling',
#   'talking',
#   'in',
#   'going.',
#   'gay',
#   'straight',
#   'Chinese!”',
#   'sorry,',
#   'biased.',
#   'gonna',
#   'on',
#   'not',
#   'not',
#   'not',
#   'wrong,',
#   'almost–',
#   'like,',
#   'just',
#   'just',
#   'sick,',
#   'joking.',
#   'armed',
#   'black,',
#   'like…',
#   'not',
#   'looking',
#   'in',
#   'sleepin’,',
#   'like,',
#   'not',
#   'just',
#   'just',
#   'talking',
#   'doing',
#   'on',
#   'canceled.”',
#   'freezing',
#   'at',
#   'inheritin’'],
#  'really': ['asking:',
#   'fair',
#   'know',
#   'want',
#   'fucking',
#   'fuckin’',
#   'fightin’.',
#   'bad.',
#   'crazy',
#   'hard',
#   'cold.”',
#   'upset.',
#   'the'],
#  'asking:': ['how'],
#  'here?': ['I'],
#  'mean,': ['what', 'it’s', 'you', 'but', 'really,', 'they'],
#  'what': ['the',
#   'do',
#   'I’m',
#   'it',
#   'the',
#   'the',
#   'they',
#   'I',
#   'did',
#   'were',
#   'I',
#   'I',
#   'the',
#   'I',
#   'I',
#   'I',
#   'he',
#   'you',
#   'he',
#   'I',
#   'he',
#   'you',
#   'I',
#   'Kevin',
#   'you',
#   'that’s',
#   'I',
#   'I',
#   'you…”',
#   'I',
#   'I',
#   'the',
#   'are',
#   'I',
#   'your',
#   'the',
#   'I',
#   'I',
#   'this',
#   'to',
#   'I',
#   'they',
#   'we',
#   'I',
#   'it',
#   'I',
#   'it',
#   'happened',
#   'they',
#   'happened.”',
#   'did',
#   'it’s',
#   'I',
#   'that',
#   'you'],
#  'fuck': ['is',
#   'it!',
#   'do',
#   'up.”',
#   'anybody',
#   'up,',
#   'up',
#   'up.',
#   'is',
#   'what',
#   'up',
#   'are',
#   'is',
#   'is'],
#  'this?': ['But'],
#  'But': ['what',
#   'if',
#   'when',
#   'he’s',
#   'that’s',
#   'I',
#   'you',
#   'it',
#   'if',
#   'I’m',
#   'just',
#   'if',
#   'the',
#   'they’re',
#   'they',
#   'born',
#   'the',
#   'I’m',
#   'eight',
#   'you',
#   'it’s',
#   'I',
#   'you',
#   'what',
#   'lucky'],
#  'do': ['I',
#   'something',
#   'anything',
#   'not',
#   'it…',
#   'it',
#   'I',
#   'that?',
#   'in',
#   'anything',
#   'that,',
#   'I',
#   'so',
#   'if',
#   'what',
#   'it?”',
#   'it.',
#   'you',
#   'you',
#   'something.”',
#   'you',
#   'anything'],
#  'know?': ['I’m'],
#  'just': ['Morgan',
#   'never',
#   'tryin’',
#   'trying',
#   'beat',
#   'forgot',
#   'remember,',
#   'to',
#   'a',
#   'can’t',
#   'one',
#   'travel',
#   'driving',
#   'know',
#   'be',
#   'sittin’',
#   'feels',
#   'be',
#   'said',
#   'shut',
#   'when',
#   'walking',
#   'be',
#   'kind',
#   'came',
#   'killed',
#   'talked',
#   'gonna',
#   'being',
#   'don’t',
#   'pops',
#   'waving',
#   'like',
#   'pepper',
#   '“peppering',
#   'afraid',
#   'French.',
#   'know',
#   'turn',
#   'threw',
#   'financial',
#   'gotta',
#   'penetrate'],
#  'Freeman.': ['Anyway,'],
#  'Anyway,': ['I'],
#  'guess': ['what', 'who', 'who', 'is…', 'is…'],
#  'trying': ['to', 'to', 'to', 'to', 'to', 'to'],
#  'to': ['say',
#   'run',
#   'an',
#   'me.',
#   'buy',
#   'Foot',
#   'catch',
#   'get',
#   'this',
#   'kill',
#   'him',
#   'do.',
#   'get',
#   'see',
#   'take',
#   'me.',
#   'entertain',
#   'be',
#   'know',
#   'say.',
#   'me',
#   'go',
#   'school',
#   'Hawaii.',
#   'look',
#   'catch.”',
#   'be',
#   'be',
#   'be',
#   'the',
#   'shut',
#   'work',
#   'be',
#   'get',
#   'host',
#   'myself,',
#   'perfect',
#   'offend',
#   'go',
#   'be',
#   'buy',
#   'break',
#   'Kevin',
#   'that',
#   'go',
#   'Standards',
#   'defend',
#   'me.',
#   'learn',
#   'upset…',
#   'conjure',
#   'write',
#   'me.',
#   'get',
#   'where',
#   'go.”',
#   'the',
#   'the',
#   'the',
#   'themselves.',
#   'use',
#   'get',
#   'take',
#   'admit',
#   'me,',
#   'me?',
#   'go',
#   'write',
#   'think',
#   'go',
#   'the',
#   'be',
#   'men,',
#   'play',
#   'be',
#   'watch',
#   'work.',
#   'masturbate.',
#   'try.',
#   'do',
#   'shut',
#   'choose',
#   'choose,',
#   'consult',
#   'be',
#   'us,',
#   'have',
#   'pay.',
#   'give',
#   'get',
#   'stop',
#   'change',
#   'do',
#   'shoot',
#   'tell',
#   'tell',
#   'me.',
#   'your',
#   'shoot',
#   'save',
#   'worry.',
#   'meet?',
#   'me…',
#   'disarm',
#   'save',
#   'save',
#   'do.',
#   'get',
#   'see.',
#   'us?',
#   'your',
#   'the',
#   'a',
#   'be',
#   'this',
#   'my',
#   'Kmart.',
#   'the',
#   'me.',
#   'pepper',
#   'trick',
#   'buy',
#   'the',
#   'that',
#   'him',
#   'Chicago?',
#   'be',
#   'them.',
#   'have',
#   'touch',
#   'him,',
#   'overcome',
#   'call',
#   'the',
#   'get',
#   'get',
#   'not',
#   'go',
#   'the',
#   'the',
#   'count',
#   'get',
#   'myself,',
#   'listen',
#   'you',
#   'Nirvana',
#   'the'],
#  'say': ['is\xa0if',
#   'anything…',
#   '2000-zero-zero',
#   'something',
#   'that.',
#   'that',
#   'on',
#   'the',
#   'the',
#   'the',
#   'it,',
#   'the',
#   'gets',
#   'anything',
#   'LeBron',
#   'in',
#   'or',
#   'no.',
#   'I’m',
#   'that.',
#   'it'],
#  'is\xa0if': ['you'],
#  'you': ['say',
#   'risk',
#   'don’t',
#   'ready?',
#   'can',
#   'do',
#   'haven’t',
#   'know',
#   'that',
#   'know',
#   'know,',
#   'like',
#   'guys',
#   'believe',
#   'ever',
#   'need',
#   'lying,',
#   'know',
#   'at',
#   'clicked',
#   'imagine',
#   'something.',
#   'know',
#   'what',
#   'don’t',
#   'cannot',
#   'what',
#   'can',
#   'should',
#   'can',
#   'are',
#   'see,',
#   'the',
#   'do',
#   'are',
#   'hear',
#   'think',
#   'know',
#   'to',
#   'want',
#   'know',
#   'go.',
#   'hear',
#   'pull',
#   'for',
#   'just',
#   'okay?',
#   'feel',
#   'could…',
#   'were',
#   'supposed',
#   'see',
#   'can',
#   'to',
#   'guys',
#   'right',
#   'have',
#   'need',
#   'decide',
#   'can',
#   'to',
#   'know',
#   'know',
#   'know',
#   'understand',
#   'have',
#   'training',
#   'skipped',
#   'tried',
#   'feel,',
#   'know',
#   'know',
#   'finally',
#   'realize',
#   'want?”',
#   'wanted',
#   'want?”',
#   'have',
#   'load',
#   'load',
#   'gotta',
#   'that',
#   'that',
#   'don’t',
#   'imagine',
#   'was',
#   'going?',
#   'see',
#   'have',
#   'remember',
#   'get',
#   'know.',
#   'know,',
#   'faggot',
#   'if',
#   'look',
#   'are,',
#   'forget',
#   'want',
#   'can',
#   'to',
#   'want',
#   'what.',
#   'know.',
#   'know',
#   'very',
#   '♪\n♪',
#   'sow'],
#  'anything…': ['you'],
#  'risk': ['everything.'],
#  'everything.': ['But', 'I'],
#  'if': ['that’s',
#   'it',
#   'you',
#   'you',
#   'he',
#   'Michael',
#   'I',
#   'I’m',
#   'you',
#   'his',
#   'you’re',
#   'you’re',
#   'I',
#   'we',
#   'I’m',
#   'it',
#   'it',
#   'I',
#   'I',
#   'women',
#   'this',
#   'he’s',
#   'you',
#   'I’m',
#   'somebody',
#   'you’re',
#   'you',
#   'you’re',
#   'he',
#   'you',
#   'I',
#   'I'],
#  'that’s': ['the',
#   'not',
#   'too',
#   'an',
#   'who.',
#   'gay.”',
#   'called',
#   'about.',
#   'the',
#   'a',
#   'going',
#   'gonna',
#   'going',
#   'gotta',
#   'it'],
#  'way': ['it’s',
#   'from',
#   'is',
#   'in',
#   'you’re',
#   'to',
#   'they’ll',
#   'out',
#   'Sentence',
#   '♪\n♪',
#   '♪\n♪'],
#  'gotta': ['be—okay,',
#   'guess',
#   'be',
#   'teach',
#   'give',
#   'say,',
#   'be',
#   'hurt.',
#   'picture',
#   'do',
#   'act',
#   'get'],
#  'be—okay,': ['fine,'],
#  'fine,': ['fuck'],
#  'it!': [''],
#  '': ['Ahahah,'],
#  'Ahahah,': ['he’s'],
#  'he’s': ['back',
#   'in',
#   'been',
#   'like,',
#   'a',
#   'coming',
#   'able',
#   'supposed',
#   'digging',
#   'on',
#   'a',
#   'walking',
#   'walking'],
#  'back': ['folks!', 'on', 'seat', 'talking', 'playing', 'up,', 'at'],
#  'folks!': ['Sticks'],
#  'streamed': ['August'],
#  'August': ['26,'],
#  '26,': ['2019'],
#  '2019': ['on'],
#  'on': ['Netflix.',
#   'his',
#   'inside.',
#   'the',
#   '“He',
#   'stage,',
#   'a',
#   'the',
#   'Netflix,',
#   'my',
#   'the',
#   'every',
#   'television.',
#   'our',
#   '’em.',
#   'everybody’s',
#   'the',
#   'the',
#   'my',
#   'his',
#   'his',
#   'him.',
#   'the',
#   'the',
#   'who',
#   'this',
#   'him,',
#   'down',
#   'the',
#   'the',
#   'my',
#   'my',
#   'the',
#   'it.',
#   'it?”',
#   'it?',
#   'drugs.',
#   'the',
#   'a',
#   'and',
#   'him',
#   'the',
#   'in',
#   'stage,',
#   'this',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'your',
#   'your',
#   'yourself'],
#  'Netflix.': ['“TELL'],
#  '“TELL': ['ME'],
#  'ME': ['SOMETHING’', 'NOTHIN’'],
#  'SOMETHING’': ['YOU'],
#  'YOU': ['MOTHAFUCKAS\nCAN’T'],
#  'MOTHAFUCKAS\nCAN’T': ['TELL'],
#  'TELL': ['ME'],
#  'NOTHIN’': ['I’D'],
#  'I’D': ['RATHER'],
#  'RATHER': ['DIE'],
#  'DIE': ['THAN\nTO'],
#  'THAN\nTO': ['LISTEN'],
#  'LISTEN': ['TO'],
#  'TO': ['YOU…”', 'LOVE'],
#  'YOU…”': ['—KENDRICK'],
#  '—KENDRICK': ['LAMAR,\nPULITZER'],
#  'LAMAR,\nPULITZER': ['PRIZE'],
#  'PRIZE': ['WINNER'],
#  'WINNER': ['“I'],
#  '“I': ['KNOW',
#   'don’t',
#   'asked',
#   'wouldn’t',
#   'wonder',
#   'need',
#   'work',
#   'warned',
#   'got',
#   'fuckin’',
#   'should'],
#  'KNOW': ['REAL'],
#  'REAL': ['NIGGAS\nHAPPEN'],
#  'NIGGAS\nHAPPEN': ['TO'],
#  'LOVE': ['IT”'],
#  'IT”': ['—SHAWN'],
#  '—SHAWN': ['CARTER\n(BILLIONAIRE)'],
#  'CARTER\n(BILLIONAIRE)': ['♪'],
#  '♪': ['I', 'And', 'Trying', 'Good', 'They', 'I', 'My', '–', 'Got', 'By'],
#  'was': ['dreaming',
#   'Judgment',
#   'all',
#   'an',
#   'so',
#   'in',
#   'home',
#   'in',
#   'in',
#   'a',
#   'home',
#   'being',
#   'sticking',
#   'molesting',
#   'it?',
#   'the',
#   'my',
#   'my',
#   'bad,',
#   'doing',
#   'like,',
#   'too',
#   'because,',
#   'so',
#   'mentioned.',
#   'fuckin’',
#   'like,',
#   '36,',
#   'Kevin',
#   'thinking',
#   'gonna',
#   'a',
#   'demonstrating',
#   'furious.',
#   'joking.',
#   'upset,',
#   'when',
#   'doing',
#   '15',
#   'one',
#   'leaving,',
#   'a',
#   'saying…',
#   'hot.',
#   'Chinese?',
#   'a',
#   'his',
#   'masturbating',
#   'gonna',
#   'tone',
#   'cookin’.',
#   'like,',
#   'like,',
#   'telling',
#   'like,',
#   'like,',
#   'looking',
#   'driving,',
#   'coming',
#   'out.',
#   'home.',
#   'fine.',
#   'a',
#   'fucked',
#   'like…',
#   'like,',
#   'a',
#   'sittin’',
#   'mad',
#   'unarmed.',
#   'just,',
#   'nervous,',
#   'on',
#   'sweating.',
#   'like…',
#   'bird',
#   'trying',
#   'like,',
#   'not',
#   'familiar',
#   'in',
#   'the',
#   'the',
#   'a',
#   'furious,',
#   'up',
#   'talking',
#   'clearly',
#   'a',
#   'minus',
#   'last',
#   'awful.',
#   'a',
#   'talking',
#   'a',
#   'even',
#   'once',
#   'a',
#   '12',
#   'like,',
#   '12',
#   'laughing,',
#   'really'],
#  'dreaming': ['When'],
#  'When': ['I'],
#  'wrote': ['this'],
#  'this': ['♪\n♪',
#   'morning',
#   'is',
#   'nigga',
#   'nigga',
#   'room',
#   'molesting,',
#   'chick,',
#   'point',
#   'is',
#   'nigga',
#   'nigga.',
#   'is',
#   '14-year-old',
#   'woman',
#   'shit',
#   'world',
#   'is',
#   'nigga',
#   'was',
#   'car.',
#   'car.”',
#   'idea',
#   'idea',
#   'nigga',
#   'guy',
#   'nigga’s',
#   'nation',
#   'one.',
#   'motherfucker,',
#   'new',
#   'other',
#   'is',
#   'is?',
#   'shit.',
#   'shit',
#   'a',
#   'country',
#   'country',
#   'is',
#   'shit',
#   'guy',
#   'motherfucker',
#   'bitch.”',
#   'person',
#   'shit.',
#   'shit',
#   'nigga',
#   'nigga',
#   'time,',
#   'kid’s',
#   'kid.',
#   'hell!',
#   'hell.”',
#   'shit'],
#  '♪\n♪': ['Forgive',
#   'But',
#   'Could’ve',
#   'Sky',
#   'You',
#   'Party',
#   'So,',
#   'Like',
#   'Got',
#   'I',
#   'I',
#   'Money',
#   'Tell',
#   'You',
#   'I’d',
#   'My',
#   'Your',
#   'Dodgin’',
#   'Stackin’',
#   'Sippin’',
#   'Diamond',
#   'Beach',
#   'Baby',
#   'I’ve',
#   'Freakin’',
#   'Eat',
#   'Yoga',
#   'Watchin’',
#   'Phone',
#   'Sex,',
#   'Look',
#   'Motherfucker,',
#   'You',
#   'You',
#   'You',
#   'You',
#   'Tell',
#   'Gonna',
#   'Peace',
#   'Sex,',
#   'Mommy',
#   'Why',
#   'Mommy',
#   'Why'],
#  'Forgive': ['me'],
#  'me': ['if',
#   'about',
#   'get',
#   'qualify',
#   'like,',
#   'up.',
#   'about.',
#   'tell',
#   'to',
#   'fuckin’',
#   'up.',
#   'down.',
#   'and',
#   'right',
#   'a',
#   'and',
#   'of?',
#   'of',
#   'up.',
#   'what',
#   'talk',
#   'while',
#   'somethin’',
#   'nothin’',
#   'when'],
#  'it': ['goes',
#   'was',
#   'out.',
#   'looks',
#   'goes.',
#   'is',
#   'is,',
#   'goes.',
#   'wasn’t',
#   'must’ve',
#   'seems',
#   'was',
#   'comes',
#   'was',
#   'was',
#   'was',
#   'from',
#   'was',
#   'over',
#   'out.',
#   'occurred',
#   'that…',
#   'be',
#   'happened',
#   'happened',
#   'would',
#   'did?',
#   'actually',
#   'in',
#   'is',
#   'was',
#   'is.',
#   'was',
#   'either.',
#   'up,',
#   'is.',
#   'was',
#   'everyday.',
#   'reminds',
#   'right.',
#   'started',
#   'may,',
#   'to',
#   'means',
#   'like',
#   'out.',
#   'goes.',
#   'hurts,',
#   'was',
#   'all',
#   'for',
#   'would',
#   'to',
#   'in',
#   'costs',
#   'is',
#   'on',
#   'rotate'],
#  'goes': ['astray', 'just', 'like'],
#  'astray': ['♪\n♪'],
#  'when': ['I',
#   'he',
#   'the',
#   'I',
#   'it',
#   'he',
#   'I',
#   'you',
#   'that',
#   'I',
#   'dinner’s',
#   'y’all',
#   'the',
#   'Dick',
#   'you',
#   'he’s',
#   'the',
#   'did',
#   'I',
#   'I',
#   'you’re',
#   'destruction'],
#  'woke': ['up'],
#  'up': ['this',
#   'and',
#   'to',
#   'Rihanna.”',
#   'so',
#   'on',
#   'with',
#   'on',
#   'from',
#   'their',
#   'school',
#   'just',
#   'and',
#   'nicely.”',
#   'and',
#   'out',
#   'nice.”',
#   'in',
#   'at',
#   'to',
#   'without',
#   'to,',
#   'here.”',
#   'in',
#   'to',
#   'the',
#   'in'],
#  'morning': ['♪\n♪'],
#  'Could’ve': ['sworn'],
#  'sworn': ['it'],
#  'Judgment': ['Day'],
#  'Day': ['♪\n♪'],
#  'Sky': ['was'],
#  'all': ['purple',
#   'the',
#   'the',
#   'these',
#   'this',
#   'the',
#   'of',
#   'have',
#   'those',
#   'the',
#   'kinds',
#   'those',
#   'the',
#   'the',
#   'my',
#   'just',
#   'depends…',
#   'over',
#   'over',
#   'over',
#   'these',
#   'by',
#   'right?',
#   'this',
#   'kinds',
#   'over',
#   'this',
#   'the',
#   'kinds',
#   'three',
#   'the',
#   'them',
#   'I’m',
#   'the',
#   'the'],
#  'purple': ['♪\n♪There'],
#  '♪\n♪There': ['were'],
#  'were': ['people',
#   'gonna',
#   'those',
#   'Kevin’s',
#   'breaking',
#   'right.',
#   'going,',
#   'like',
#   'so',
#   'supporting',
#   'walking?',
#   'walking.',
#   'you',
#   'both,',
#   'they',
#   'very,',
#   'Nigerian,'],
#  'running': ['everywhere'],
#  'everywhere': ['♪'],
#  'And': ['this',
#   'when',
#   'they',
#   'then,',
#   'if',
#   'that',
#   'you',
#   'I’m',
#   'I',
#   'when',
#   'it',
#   'if',
#   'I',
#   'he',
#   'I',
#   'I’m',
#   'it',
#   'I’m',
#   'then',
#   'I',
#   'all',
#   'in',
#   'then',
#   'then',
#   'if',
#   'remember,',
#   'as',
#   'she',
#   'if',
#   'I',
#   'I',
#   'these',
#   'the',
#   'sitting',
#   'then,',
#   'just',
#   'he',
#   'they',
#   'it’s',
#   'for',
#   'everyone',
#   'it',
#   'he',
#   'ladies,',
#   'if',
#   'meanwhile,',
#   'I',
#   'my',
#   'he',
#   'we',
#   'you',
#   'me',
#   'then,',
#   'my',
#   'while',
#   'I',
#   'you',
#   'anyone',
#   'I',
#   'as',
#   'then,',
#   'all',
#   'as',
#   'remember,',
#   'I',
#   'the',
#   'then',
#   'he',
#   'I’m',
#   'I',
#   'she’s',
#   'there',
#   'that',
#   'then,',
#   'I',
#   'I’ll',
#   'one',
#   'everybody',
#   'I',
#   'unfortunately',
#   'I',
#   'my',
#   'he',
#   'I',
#   'my',
#   'I',
#   'my',
#   'all'],
#  'bar': ['of'],
#  'of': ['the',
#   'Atlanta,',
#   'time',
#   'the',
#   'that.',
#   'the',
#   'the',
#   'them?',
#   'dumb,',
#   'the',
#   'America…',
#   'it.',
#   'Pop.',
#   'our',
#   'mine',
#   'sex',
#   'tapes.',
#   'a',
#   'such',
#   'nigga',
#   'hosting',
#   'being',
#   'gay',
#   'gay',
#   'them,',
#   'them,',
#   'them',
#   'Motion',
#   'my',
#   'show',
#   'the',
#   'all',
#   'letters.',
#   'here.',
#   'something',
#   'him',
#   'you,',
#   'us.',
#   'my',
#   'trouble',
#   'mine',
#   'hung',
#   'my',
#   'this.',
#   'that',
#   'shit.',
#   'us',
#   'us',
#   'us.',
#   'thought.',
#   'y’all',
#   'poor',
#   'it.',
#   'fact,',
#   'the',
#   'these',
#   'a',
#   'me.',
#   'us.',
#   'crack…',
#   'shells',
#   'some',
#   'some',
#   'the',
#   'the',
#   'a',
#   'my',
#   'bed…',
#   'it.',
#   'dying',
#   'being',
#   'us.',
#   'Jussie',
#   'a',
#   'the',
#   'niggas',
#   'being',
#   'these',
#   'shit.',
#   'you',
#   'poor',
#   'my',
#   'him',
#   'this',
#   'this',
#   'kids',
#   'marriages'],
#  'whole': ['song.', 'shit.', 'country', 'story'],
#  'song.': ['Prince'],
#  'Prince': ['say…'],
#  'say…': ['♪', 'say'],
#  'Trying': ['to'],
#  'run': ['from', 'in'],
#  'from': ['my',
#   'the',
#   'the',
#   'the',
#   'you,',
#   'now.',
#   'Home',
#   'me',
#   '’em.',
#   'these',
#   'the',
#   'the',
#   'itself.',
#   'itself,',
#   'France.',
#   'Empire?”',
#   'Empire?”',
#   'there.”',
#   'a'],
#  'my': ['destruction',
#   'man…',
#   'sons',
#   'show',
#   'impression,',
#   'impression…',
#   'FUCKING',
#   'ears',
#   'weekend?',
#   'dick!',
#   'first',
#   'money',
#   'dressing',
#   'documentary,',
#   'life.”',
#   'life.”',
#   'client',
#   'face.',
#   'words.',
#   'career.',
#   'favorite',
#   'fuckin’',
#   'guess',
#   'guess',
#   'fault.',
#   'jokes.',
#   'own,',
#   'life,',
#   'last',
#   'dick',
#   'money,',
#   'choice.',
#   'son',
#   'man,',
#   'man.',
#   'eyes.',
#   'wife',
#   'shows',
#   'trans',
#   'son’s',
#   'sons',
#   'experience,',
#   'car',
#   'car',
#   'property,',
#   'property?”',
#   'car',
#   'property,',
#   'wife',
#   'dick',
#   'pajamas.',
#   'God,',
#   'father,',
#   'dad',
#   'outfits',
#   'dad',
#   'dad',
#   'anus',
#   'life',
#   'DNA',
#   'DNA',
#   'DNA',
#   'heritage,',
#   'fate'],
#  'destruction': ['♪\n♪', 'Gonna'],
#  'You': ['know',
#   'ever',
#   'ready?',
#   'gotta',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know',
#   'know…',
#   'know,',
#   'gotta',
#   'supposed',
#   'know',
#   'would',
#   'know',
#   'know,',
#   'know',
#   'should',
#   'need',
#   'know',
#   'know',
#   'would',
#   'know,',
#   'read',
#   'know',
#   'ever',
#   'know',
#   'probably',
#   'got',
#   'know,',
#   'know,',
#   'know',
#   'know',
#   'know',
#   'see,',
#   'can’t',
#   'left',
#   'were',
#   'were',
#   'are',
#   'are',
#   'don’t',
#   'ashamed',
#   'motherfuckers',
#   'ain’t',
#   'ain’t',
#   'ain’t',
#   'ain’t'],
#  'know': ['I',
#   'what',
#   'all',
#   'what',
#   'what?',
#   'what',
#   'what',
#   'more',
#   'how',
#   'it',
#   'why',
#   'why',
#   'how',
#   'this',
#   'anything!',
#   'anything',
#   'you',
#   'what',
#   'what',
#   'about',
#   'Kevin',
#   'what',
#   'I’d',
#   'why',
#   'I',
#   'that',
#   'who',
#   'how',
#   'these',
#   'what',
#   'the',
#   'what',
#   'what',
#   'what',
#   'where',
#   'if',
#   'for',
#   'what',
#   'what',
#   'what',
#   'nobody',
#   'why',
#   'what',
#   'what',
#   'what',
#   'which',
#   'for',
#   'the',
#   'what',
#   'what’s',
#   'what',
#   'what',
#   'what',
#   'what',
#   'that',
#   'who',
#   'white',
#   'who',
#   'that',
#   'that',
#   'that',
#   'what',
#   'what'],
#  'didn’t': ['even',
#   'listen',
#   'do',
#   'even',
#   'even',
#   'know',
#   'try',
#   'realize',
#   'come',
#   'do',
#   'have',
#   'want',
#   'know',
#   'have',
#   'want',
#   'ask',
#   'know.',
#   'know',
#   'understand',
#   'know',
#   'say',
#   'scream'],
#  'even': ['care',
#   'suggested',
#   'around',
#   'sound',
#   'show',
#   'got',
#   'know',
#   'say',
#   'the',
#   'have',
#   'held',
#   'know',
#   'felt',
#   'puttin’'],
#  'care': ['♪', 'when', 'what', 'anymore.', 'either.'],
#  'Good': ['people'],
#  'Atlanta,': ['we'],
#  'must': ['never', 'register'],
#  'never': ['forget…',
#   'saw',
#   'occurred',
#   'did',
#   'say',
#   'seen',
#   'hear',
#   'dreamt',
#   'heard',
#   'heard',
#   'occurred',
#   'even',
#   'heard',
#   'say',
#   'feel',
#   'forget',
#   'on,'],
#  'forget…': ['that'],
#  'Anthony': ['Bourdain…', 'Bourdain'],
#  'Bourdain…': ['Yeah!'],
#  'Yeah!': ['…killed', 'Everything'],
#  '…killed': ['himself.'],
#  'himself.': ['Anthony', 'He’s'],
#  'Bourdain': ['had'],
#  'had': ['the',
#   'nothing…',
#   'in',
#   'in',
#   'had.',
#   'made',
#   'to',
#   'written',
#   'the',
#   'to',
#   'to',
#   'to',
#   'a',
#   'chicken',
#   'to',
#   'parked',
#   'a',
#   'a',
#   'a'],
#  'greatest': ['job'],
#  'job': ['that', 'hung', 'that', 'well,'],
#  'show': ['business',
#   'a',
#   'in',
#   'it.',
#   'in',
#   'business.',
#   'called',
#   'somewhere,',
#   'Michael'],
#  'business': ['ever'],
#  'ever': ['produced.',
#   'seen',
#   'tried',
#   'to',
#   'heard',
#   'had',
#   'had',
#   'seen,',
#   'seen.',
#   'mentioned',
#   'worked',
#   'say',
#   'seen',
#   'seen.',
#   'come',
#   'heard',
#   'forget',
#   'been',
#   'recover',
#   'thought'],
#  'produced.': ['This'],
#  'nigga': ['flew',
#   'in',
#   'from',
#   'to',
#   'has',
#   'at',
#   'read',
#   'dreams',
#   'a',
#   'probably',
#   'body.',
#   'with',
#   'was',
#   'is.',
#   'a'],
#  'flew': ['around'],
#  'around': ['the', 'him.', 'the', 'making', 'his', 'his'],
#  'world…': ['…and'],
#  '…and': ['ate'],
#  'ate': ['delicious'],
#  'delicious': ['meals'],
#  'meals': ['with'],
#  'with': ['outstanding',
#   'that',
#   'a',
#   'his',
#   'him',
#   'this',
#   'their',
#   'impunity…',
#   'them',
#   'this',
#   'us.',
#   'comedian',
#   'you,',
#   'duck',
#   'you.',
#   'them',
#   'the',
#   'the',
#   'a',
#   'a',
#   'him,',
#   'MAGA',
#   'our',
#   'a'],
#  'outstanding': ['people.'],
#  'people.': ['That', 'You', 'They'],
#  'That': ['man',
#   'nigga.',
#   'does',
#   'was',
#   'makes',
#   'wouldn’t',
#   'was',
#   'click-clack',
#   'wasn’t'],
#  'man': ['with', 'had', 'before', 'should'],
#  'hung': ['himself', 'out,'],
#  'himself': ['in', 'into'],
#  'luxury': ['suite'],
#  'suite': ['in'],
#  'France.': ['♪', 'A-And'],
#  'They': ['say',
#   'said',
#   'gonna',
#   'even',
#   'call',
#   'just',
#   'just',
#   'seem',
#   'just',
#   'all',
#   'ruined',
#   'just',
#   'have',
#   'gonna',
#   'can’t',
#   'are',
#   'are',
#   'don’t',
#   'would',
#   'were'],
#  '2000-zero-zero': ['♪\n♪'],
#  'Party': ['over,'],
#  'over,': ['oops,'],
#  'oops,': ['out'],
#  'out': ['of',
#   'drinking',
#   'about',
#   'doing',
#   'here',
#   'with',
#   'now.',
#   'in',
#   'of',
#   'when',
#   'the',
#   'for',
#   'of',
#   'here?”',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'a',
#   'of',
#   'where',
#   'and',
#   'of',
#   'of',
#   '300',
#   'the'],
#  'time': ['♪\n♪', 'ever', 'ago.', 'and', 'on', 'in'],
#  'So,': ['tonight', 'in', 'figure', 'I', 'which', 'first,', 'okay.'],
#  'tonight': ['I’m', 'I'],
#  'gonna': ['party',
#   'get',
#   'do',
#   'try',
#   'try',
#   'be',
#   'say',
#   'want',
#   'put',
#   'tell',
#   'know',
#   'host',
#   'repeat',
#   'do',
#   'pull',
#   'say',
#   'hurt',
#   'get',
#   'be',
#   'get',
#   'be'],
#  'party': ['♪\n♪'],
#  'Like': ['it’s', 'I', 'that.'],
#  '1999': ['♪'],
#  'knew': ['a'],
#  'school': ['that',
#   'with',
#   'the',
#   'going,',
#   'today,',
#   'shooting',
#   'and',
#   'is'],
#  'an': ['urban',
#   'Ivy',
#   'above',
#   'impression',
#   'interview',
#   'idiot.',
#   'awfully',
#   'African',
#   'unwritten',
#   'expensive',
#   'old',
#   'actor',
#   'abomination'],
#  'urban': ['genius.'],
#  'genius.': ['This'],
#  'motherfucker’s': ['grades'],
#  'grades': ['was'],
#  'so': ['good,',
#   'a',
#   'bad',
#   'bad',
#   'much',
#   'we',
#   'confusing.',
#   'much,',
#   'I',
#   'well',
#   'sleepy',
#   'hard',
#   'quiet',
#   'you’ve',
#   'he'],
#  'good,': ['he'],
#  'got': ['all',
#   'himself',
#   'divorced,',
#   'two.',
#   'his',
#   'to',
#   'another',
#   'poor',
#   'the',
#   'a',
#   'friends',
#   'friends',
#   'friends',
#   'a',
#   'a',
#   'in',
#   'home',
#   'up',
#   'a',
#   'it',
#   'far',
#   '$1.50.',
#   'a',
#   'one',
#   'rope?',
#   'rope?',
#   'all',
#   'really',
#   'royalty',
#   'royalty',
#   'loyalty,',
#   'royalty',
#   'winners'],
#  'hood': ['to'],
#  'Ivy': ['League'],
#  'League': ['school'],
#  'full': ['scholarship.', 'of'],
#  'scholarship.': ['From'],
#  'From': ['there,'],
#  'there,': ['the', 'Whites.'],
#  'motherfucker': ['got', 'is', 'is', 'the', 'like', 'up?', 'in'],
#  'into': ['one', 'character.', 'how', 'the'],
#  'one': ['of',
#   'of',
#   'black',
#   'of',
#   'of',
#   'big',
#   'thing',
#   'of',
#   'of',
#   'of',
#   'thing',
#   'was',
#   'of',
#   'with',
#   'more',
#   'night,',
#   'second,',
#   'day'],
#  'best': ['law', '14-year-old', 'of'],
#  'law': ['schools', 'school,', 'school,', 'school.'],
#  'schools': ['in'],
#  'country.': ['And', 'And'],
#  'school,': ['he', 'and', 'too.', 'nigga?', 'nigga.'],
#  'met': ['a'],
#  'woman': ['and', 'was'],
#  'they': ['fell',
#   'were',
#   'got',
#   'said.',
#   'don’t',
#   'didn’t',
#   'had',
#   'put',
#   'went',
#   'have',
#   'pick',
#   'make',
#   'need',
#   'have',
#   'acting',
#   'said',
#   'have',
#   'shouldn’t',
#   'exercise',
#   'make',
#   'practice',
#   'have',
#   'say',
#   'make',
#   'fucking',
#   'say.',
#   'talk',
#   'didn’t',
#   'have',
#   'put',
#   'were',
#   'not',
#   'were'],
#  'fell': ['in'],
#  'love.': ['And', 'He'],
#  'married.': ['I'],
#  'remember': ['him', 'when', 'seeing?'],
#  'him': ['telling',
#   'again',
#   'that',
#   'or',
#   'had',
#   'and',
#   'get',
#   'up',
#   'up',
#   'up.',
#   'all',
#   'and',
#   'with',
#   'and',
#   'so'],
#  'telling': ['me', 'me,', 'other', 'you', 'jokes', 'my', 'me,'],
#  'about': ['it.',
#   'it,',
#   'that',
#   'R.',
#   'the',
#   'Kevin,',
#   'the',
#   'it.',
#   'them',
#   'these',
#   'it.',
#   'it.',
#   'it.',
#   'it',
#   'this',
#   'everything.',
#   'how',
#   'Ohio',
#   'on',
#   'how',
#   'that?”',
#   'it',
#   'this',
#   'that',
#   'how'],
#  'it.': ['He',
#   'This…',
#   'This',
#   'It’s',
#   'But',
#   'I’ve',
#   'Against',
#   'You',
#   'So',
#   'Even',
#   'Like,',
#   'Okay,',
#   'Louis',
#   'Listen,',
#   'I',
#   'I',
#   'The',
#   'I',
#   'Okay,',
#   'But…'],
#  'home': ['for', 'in', 'watching', 'early', 'early,', 'when', 'with'],
#  'Christmas,': ['and'],
#  'told': ['him,',
#   'me.',
#   'me.',
#   'me,',
#   'me',
#   'you,',
#   'you.',
#   'you.',
#   'her',
#   'everybody'],
#  'him,': ['I', 'like,', 'I’m', 'I', 'but'],
#  'said,': ['“My',
#   '“I',
#   '“If',
#   '“Fuck',
#   '“Because,',
#   '“All',
#   '“Because,',
#   '“Well,',
#   '“Hey,',
#   '“Well',
#   '“What',
#   '“I',
#   '“All',
#   '“Well,',
#   '“Oh,',
#   '“It’ll',
#   '“What',
#   '“Well,',
#   '“Dave',
#   '“Well,',
#   '“Just',
#   '“I',
#   '“David,',
#   '“Poor',
#   '“It’s',
#   '“These',
#   '“Well,',
#   '“Dad,',
#   '“Of',
#   '“Great.',
#   '“Ooh…',
#   '“If'],
#  '“My': ['man,'],
#  'man,': ['my', 'somebody’s', 'I’m', 'I’ll', 'my', 'aren’t', 'you'],
#  'man…': ['save'],
#  'save': ['that', 'anybody,', 'this', 'our'],
#  'bitch': ['for', 'took'],
#  'late': ['in', 'now.', 'at', 'at'],
#  'your': ['life.”',
#   'life,',
#   'butthole',
#   'lawyer',
#   'lawyer',
#   'job',
#   'artistic',
#   'phone,',
#   'letter.',
#   'agenda,',
#   'state,',
#   'religious',
#   'school',
#   'minds',
#   'country,',
#   'dick',
#   'kids,',
#   'home',
#   'dick',
#   'fault.',
#   'belt',
#   'plate',
#   'fate'],
#  'life.”': ['But', 'She', 'Then'],
#  'listen': ['to', 'to', 'to'],
#  'me.': ['He',
#   'He',
#   'That’s',
#   'And',
#   '“Hey.',
#   '‘Cause',
#   'Fuck',
#   'I',
#   'I’d',
#   'I',
#   'I’m'],
#  'married': ['her'],
#  'her': ['while', 'like,', 'my'],
#  'while': ['he', 'he', 'I’m', 'we’re', 'you’re', 'I’m'],
#  'sadly,': ['they'],
#  'divorced,': ['while'],
#  'school.': ['He', 'I’d', 'I'],
#  'street': ['nigga', 'late', 'in'],
#  'hood.': ['This'],
#  'nothing…': ['and'],
#  'took': ['half', '20%', 'impeccable'],
#  'half': ['of', 'the'],
#  'that.': ['And', 'That', 'They', 'Just', 'The', '“Are', 'It'],
#  'then,': ['I', 'two', 'why', 'the', 'I', 'I', 'if', 'how'],
#  'saw': ['him', 'me,'],
#  'again': ['for'],
#  'years,': ['and', 'just'],
#  'two': ['years', 'new', 'years', 'boxes', 'white'],
#  'years': ['ago,',
#   'old!',
#   'from',
#   'and',
#   'ago,',
#   'later,',
#   'ago,',
#   'ago,',
#   'ago.',
#   'ago.',
#   'old.',
#   'old.'],
#  'ago,': ['I', 'I', 'Kevin', '15'],
#  'DC': ['doing'],
#  'doing': ['some',
#   'an',
#   'comedy',
#   'all',
#   'a',
#   'Chappelle’s',
#   'your',
#   'that.”',
#   'is',
#   'on',
#   'a'],
#  'some': ['shoppin’,',
#   'socks',
#   'impressions',
#   'sleep.',
#   '16',
#   'very',
#   'help?”',
#   'responsibility',
#   'shit',
#   'things.',
#   'other',
#   'drugs,',
#   'bullets,',
#   'ducks',
#   'deer.',
#   'bleach',
#   'reason,',
#   'more',
#   'way',
#   'money'],
#  'shoppin’,': ['tryin’'],
#  'tryin’': ['to', 'to'],
#  'buy': ['my', 'this', 'both'],
#  'sons': ['some', 'the'],
#  'socks': ['at'],
#  'at': ['Foot',
#   'but',
#   'the',
#   'people’s',
#   'the',
#   'your',
#   'all!',
#   'home',
#   'telling',
#   'the',
#   'the',
#   'least',
#   'what’s',
#   'the',
#   'each',
#   'at',
#   'first.',
#   'each',
#   'all,',
#   'night,',
#   'night,',
#   'all.',
#   '2:00',
#   'me?',
#   'the',
#   'it,',
#   'school.”',
#   'Four',
#   'the'],
#  'Foot': ['Locker.', 'Locker.'],
#  'Locker.': ['I', 'Guess'],
#  'go': ['to',
#   'to',
#   'through',
#   'to',
#   'around',
#   'to',
#   'through',
#   'check',
#   'to',
#   'to'],
#  'Guess': ['who’s'],
#  'who’s': ['the', 'come'],
#  'manager?': ['That'],
#  'nigga.': ['Dressed', 'Nothing.', 'Get', 'I’m', 'I’m', 'Try', 'Try', 'Will'],
#  'Dressed': ['like'],
#  'like': ['a',
#   'from',
#   'an',
#   'to',
#   'it.',
#   'to',
#   'HBO',
#   'to',
#   'how',
#   'the',
#   'this.',
#   'this',
#   'the',
#   'his',
#   'them',
#   'the',
#   'they',
#   'that.',
#   'pancake',
#   'if',
#   'the',
#   'I',
#   'us',
#   'he’s',
#   'a',
#   'a',
#   'that.',
#   'this,',
#   'this:',
#   'this.',
#   'oddly',
#   'how',
#   'that.',
#   'something…',
#   'it’s',
#   'to',
#   'it’s'],
#  'referee,': ['the'],
#  'shit.': ['This',
#   'I',
#   'You',
#   'You',
#   'But',
#   'It’s',
#   '“Son…',
#   'They',
#   'I’ve',
#   'The',
#   'Now,',
#   'The'],
#  '45': ['years'],
#  'old!': ['We'],
#  'We': ['went', 'have', 'just', 'gotta', 'was', 'were'],
#  'went': ['out', 'onstage,', 'to', 'on', 'outside', 'in'],
#  'drinking': ['that'],
#  'night': ['just', 'in'],
#  'catch': ['up,'],
#  'up,': ['and…', 'okay?', 'nigga.', 'I’m', 'unscathed.'],
#  'and…': ['and', 'cum', 'he’s', 'and…', 'put', 'and,', '-All'],
#  'said': ['he’s',
#   'he',
#   'it',
#   'he',
#   'I',
#   'it',
#   'it.',
#   'it',
#   'I',
#   'that',
#   'he’s',
#   'they',
#   'this.',
#   'it'],
#  'been': ['living',
#   'dead',
#   'molested',
#   'going',
#   'to',
#   'there.',
#   'poor,',
#   'goin’'],
#  'living': ['with'],
#  'his': ['mother',
#   'feet.',
#   'dick',
#   'little',
#   'head',
#   'phone',
#   'gender.',
#   'room.',
#   'own',
#   'own',
#   'own',
#   'face,',
#   'face.',
#   'shoulder,',
#   'yellow',
#   'teeth',
#   'neck,',
#   'neck.',
#   'way.',
#   'newspaper'],
#  'mother': ['for,'],
#  'for,': ['like,'],
#  'like,': ['ten',
#   '“Dave,',
#   '“Well,',
#   '“Nah,',
#   '“Yeah,',
#   '“You',
#   '“Man,',
#   '“This',
#   '“Your',
#   '“Ha,',
#   '“Hello?”',
#   'little',
#   '“Yeah,',
#   '“I',
#   '“Dad’s',
#   '“Yo,',
#   '“What',
#   '“Oh,',
#   '“You',
#   '“What…',
#   'a',
#   '“What',
#   '“Why',
#   '“Ick…',
#   'nowadays,',
#   '“Do',
#   'say',
#   '“Uh,',
#   'international',
#   '“Dad,',
#   'I',
#   '“What'],
#  'ten': ['years,', 'years', 'is'],
#  'feet.': ['But'],
#  'not': ['the',
#   'a',
#   'particularly',
#   'bad,',
#   'allowed',
#   'believe',
#   'Macaulay',
#   'a',
#   'say',
#   'even',
#   'gonna',
#   'my',
#   'good',
#   'one',
#   'gay.”',
#   'a',
#   'their',
#   'mean,',
#   'the',
#   'a',
#   'all',
#   'funny?',
#   'to',
#   'to',
#   'going',
#   'for',
#   'for',
#   'against',
#   'have',
#   'criminals.',
#   'exaggerating,',
#   'killing',
#   'a',
#   'rational.',
#   'killing',
#   'heroin',
#   'just',
#   'supporting',
#   'white,',
#   'supposed',
#   'poor.”',
#   'be',
#   'for'],
#  'point': ['of', 'of', 'enough.'],
#  'story.': ['The', 'He', 'Apparently,', 'He'],
#  'The': ['point',
#   'next',
#   'only',
#   'new',
#   'prosecutor',
#   'gay',
#   'rule',
#   'G’s',
#   'G’s',
#   'right',
#   'guy',
#   'other',
#   'whole',
#   'headline',
#   'whole',
#   'makin’'],
#  'story': ['is…', 'is'],
#  'is…': ['never', 'Oh!', 'the', 'gay,'],
#  'occurred': ['to', 'to', 'to'],
#  'kill': ['himself.', 'this', 'everybody', 'a', 'everybody'],
#  'He’s': ['alive', 'gonna', 'like'],
#  'alive': ['and'],
#  'well': ['in', 'in'],
#  'D.C.': ['I'],
#  'suggested': ['to'],
#  'should': ['try', 'never', 'roll', 'not', 'do', 'be', 'kill'],
#  'try': ['it', 'some', 'to', 'to', 'to'],
#  'out.': ['Like,', 'I', 'Could', 'Have', 'I', 'Just'],
#  'Like,': ['“I',
#   'damn,',
#   '“Oh,',
#   'look,',
#   'wh-why',
#   'think',
#   'if',
#   'when',
#   'when'],
#  'know,': ['maybe…”',
#   'if',
#   'it',
#   'you',
#   'ladies,',
#   'as',
#   'I',
#   'it’s',
#   'everybody’s',
#   '32,'],
#  'maybe…”': ['Nobody’s'],
#  'Nobody’s': ['life'],
#  'life': ['is', 'that', 'that'],
#  'perfect.': ['No', 'As', 'Ten'],
#  'No': ['matter'],
#  'matter': ['what', 'what', 'what', 'what', 'what'],
#  'looks': ['like'],
#  'outside,': ['you'],
#  'fuck’s': ['going'],
#  'going': ['on',
#   'on',
#   'to',
#   'on,',
#   'on,',
#   'to',
#   'on.',
#   'about',
#   'to',
#   'good.',
#   'on?”',
#   'to',
#   'on'],
#  'inside.': ['I', 'I'],
#  'have': ['a',
#   'been',
#   'told',
#   'to',
#   'a',
#   'a',
#   'friends',
#   'to',
#   'to',
#   'passed',
#   'a',
#   'the',
#   'to',
#   'the',
#   'to',
#   'school',
#   'drills',
#   'kids',
#   'no',
#   'in',
#   'to',
#   'several.',
#   'no',
#   'insight',
#   'a',
#   'any–',
#   'on?',
#   'a',
#   'it.”',
#   'three',
#   'a',
#   'a'],
#  'great': ['life,'],
#  'life,': ['but', 'but', 'duh,', 'I', 'and'],
#  'perfect': ['life,', 'as'],
# ...
#  'Rihanna.”': ['I’ll'],
#  'I’ll': ['be',
#   'tell',
#   'tell',
#   'take',
#   'fuck',
#   'be',
#   'tell',
#   'suck',
#   'go',
#   'be',
#   'tell'],
#  '“Well,': ['what',
#   'what',
#   'that’s',
#   'Renée…',
#   'what',
#   'we',
#   'I',
#   'what’s',
#   'what’s',
#   'that’s',
#   'Dad,'],
#  'she': ['do?”', 'goes,', 'keeps', 'sits', 'said,', 'was', 'hates'],
#  'do?”': ['“Dave,'],
#  'molesting': ['children.”'],
#  'children.”': ['“Well,'],
#  'those': ['kids', 'stories,', 'letters', 'letters'],
#  'kids': ['wearing', 'do,', 'rehearse', 'to', 'waiting', 'was'],
#  'wearing': ['at'],
#  'time?”': ['I'],
#  'think': ['he',
#   'I',
#   'it’s',
#   'it',
#   'about',
#   'about',
#   'that',
#   'anyway.',
#   'about',
#   'back'],
#  'what?': ['Even'],
#  'Even': ['if', 'when'],
#  'it…': ['You', 'why'],
#  'Eh…': ['I'],
#  'Jackson.': ['I'],
#  'more': ['than', 'sex', 'tense,', 'bird', 'clothes', 'kids.”'],
#  'than': ['half', 'he', 'the', 'to'],
#  'room': ['have', 'and'],
#  'molested': ['in'],
#  'their': ['lives.',
#   'wives.',
#   'father',
#   'head.',
#   'anger.',
#   'fault.',
#   'own',
#   'face',
#   'unequivocal',
#   'school.',
#   'skin',
#   'tracks.'],
#  'lives.': ['But', 'You'],
#  'wasn’t': ['no', 'in', 'it?', 'allowed', 'his'],
#  'no': ['goddamn',
#   'such',
#   'such',
#   'way…',
#   'matter',
#   'WNBA,',
#   'control',
#   'matter',
#   'one',
#   'bodyguards',
#   'grudges.',
#   'questions,'],
#  'Jackson,': ['was'],
#  'it?': ['This', 'You', 'Because', 'It’s', 'Reminds', '‘Cause…', 'That’s'],
#  'kid': ['got', 'I’m', 'from'],
#  'dick': ['sucked', 'out.”', 'for', 'over', 'out?”'],
#  'sucked': ['by', 'my'],
#  'by': ['the', 'themselves', 'myself,', 'the', 'the'],
#  'King': ['of'],
#  'Pop.': ['All'],
#  'awkward': ['Thanksgivings'],
#  'Thanksgivings': ['for'],
#  'rest': ['of', 'of', 'of', 'of'],
#  'our': ['lives.', 'network.', 'country.', 'silence.', 'faith', 'DNA'],
#  'must’ve': ['felt', 'felt'],
#  'day': ['after', 'very'],
#  'after': ['that', 'that,'],
#  'shit?': ['“Hey,', 'This'],
#  '“Hey,': ['Billy,',
#   'that',
#   'that’s',
#   'what’s',
#   'everybody,',
#   'everybody,',
#   'man.',
#   'motherfucker!”',
#   'man,'],
#  'Billy,': ['how'],
#  'weekend?”': ['“How'],
#  '“How': ['was'],
#  'weekend?': ['Michael'],
#  'dick!': ['And'],
#  'sexual': ['experience.'],
#  'experience.': ['If'],
#  'starting': ['here,'],
#  'sky’s': ['the'],
#  'limit!”': ['I'],
#  'seems': ['harsh,'],
#  'harsh,': ['but,'],
#  'but,': ['man,'],
#  'somebody’s': ['gotta'],
#  'teach': ['these'],
#  'kids.': ['There’s', 'Sittin’', 'Fuck'],
#  'There’s': ['no', 'a–', 'only', 'no', 'some', 'a'],
#  'such': ['thing', 'a', 'thing', 'a'],
#  'thing': ['as', 'as', 'that', 'that', 'that’s', 'that'],
#  'free': ['trip'],
#  'trip': ['to', 'take'],
#  'Hawaii.': ['He’s'],
#  'look': ['at', 'at', 'exactly', 'at', 'at', 'how'],
#  'butthole': ['or'],
#  'or': ['something.',
#   'even',
#   'something.',
#   'I’m',
#   'whatever.',
#   'nothing',
#   'anything.',
#   'how',
#   'nothing.',
#   'something.',
#   'howl.'],
#  'something.': ['You', 'It', 'Go', 'I'],
#  'Because': ['if', 'we'],
#  'Jackson’s': ['out'],
#  'molesting,': ['then–'],
#  'then–': ['then'],
#  'Macaulay': ['Culkin?', 'Culkin', 'Culkin’s'],
#  'Culkin?': ['Hmm?'],
#  'Hmm?': ['Macaulay'],
#  'Culkin': ['stated'],
#  'stated': ['in'],
#  'interview': ['that'],
#  'inappropriate': ['with'],
#  'him.': ['Think', 'He’d', '“Hm,', '“Hello?', 'But'],
#  'Think': ['about', 'about'],
#  'know…': ['I’m'],
#  'pedophile.': ['But'],
#  'was…': ['Macaulay', 'It', 'What'],
#  'Culkin’s': ['the'],
#  'fucking,': ['I’ll'],
#  'tell': ['you',
#   'you',
#   'me',
#   'you',
#   'you',
#   'you',
#   'my',
#   'them',
#   'me',
#   'me,',
#   'you',
#   'me'],
#  'right': ['now.', 'before', 'now.', 'now.', 'to', 'to', 'back'],
#  'hero.': ['“Hey,'],
#  'guy': ['over',
#   'makes',
#   'might',
#   'is',
#   'that',
#   'doing',
#   'was',
#   'didn’t',
#   'reached'],
#  'over': ['there',
#   'that',
#   'their',
#   'his',
#   'at',
#   'there',
#   'to',
#   'his',
#   'me.”',
#   'his',
#   'his',
#   'the',
#   'everybody’s'],
#  'there': ['fucked',
#   'with',
#   'would',
#   'was,',
#   'training',
#   'is',
#   'in',
#   'it',
#   'was'],
#  'fucked': ['the', 'up.', 'up.'],
#  'Home': ['Alone.'],
#  'Alone.': ['And'],
#  'hard': ['he', 'way', 'not', 'not', 'about', 'for'],
#  'catch.”': ['♪'],
#  'mind’s': ['telling'],
#  'me,': ['“No”',
#   'right',
#   '’cause',
#   'but',
#   '“Oh,',
#   'you’d',
#   'and',
#   '“Well,',
#   'bro.”',
#   'one',
#   'how',
#   'that',
#   'that'],
#  '“No”': ['♪'],
#  'Oh!': ['R.', 'What'],
#  'R.': ['Kelly!', 'Kelly', 'Kelly.', 'Kelly.', 'Kelly,', 'Kelly'],
#  'Kelly!': ['Well,'],
#  'Well,': ['okay.', 'then…', 'then,'],
#  'okay.': ['R.', 'There’s', 'I’m'],
#  'Kelly': ['is', 'sounded'],
#  'different.': ['I'],
#  'bettin’': ['man,'],
#  'put': ['my', 'so', 'two', 'a', 'some', 'a', 'more'],
#  'money': ['on', 'in', 'from'],
#  '“He': ['probably'],
#  'probably': ['did', 'got', 'gonna', 'will'],
#  'shit.”': ['I’m'],
#  'pretty': ['sure'],
#  'sure': ['he', 'there’s', 'is', 'enough,', 'when'],
#  'okay,': ['so'],
#  'couple': ['years'],
#  'Detroit.': ['And'],
#  'sitting': ['backstage', 'next'],
#  'backstage': ['in'],
#  'dressing': ['room'],
#  'friend': ['of', 'of', 'with'],
#  'mine': ['comes', 'before'],
#  'comes': ['by,', 'out,', 'out,', 'to', 'to'],
#  'by,': ['this'],
#  'chick,': ['Dream'],
#  'Dream': ['Hampton.'],
#  'Hampton.': ['Dream,'],
#  'Dream,': ['uh,'],
#  'before': ['I’m', 'him', 'he'],
#  'stage,': ['she', 'and'],
#  'goes,': ['“Dave,', '“That', '“Oh,'],
#  'working': ['on'],
#  'Kelly.': ['“Would', 'And'],
#  '“Would': ['you'],
#  'it?”': ['And', 'Yeah.', 'He'],
#  '“Nah,': ['bitch,'],
#  'bitch,': ['I’m', 'you'],
#  'cool.”': ['I'],
#  'onstage,': ['I'],
#  'forgot': ['about'],
#  'shit,': ['and', 'look', 'but'],
#  'later,': ['the'],
#  'Surviving': ['R.'],
#  'Dream’s': ['promotin’'],
#  'promotin’': ['shit'],
#  'shit': ['and',
#   'on',
#   'they',
#   'out',
#   'out',
#   'they',
#   'is',
#   'is',
#   'out',
#   'they',
#   'was,',
#   'that',
#   'was',
#   'as',
#   'Without',
#   'Without'],
#  'keeps': ['bringing'],
#  'bringing': ['me'],
#  'up.': ['She', 'I', 'I', 'We’ll', 'Shut', 'I’m', 'She', '“David.', 'Tied'],
#  'She': ['said,', 'was', 'tells', 'said,', 'was', 'was'],
#  'asked': ['Dave'],
#  'documentary,': ['and'],
#  'too': ['hot', 'hot', 'late'],
#  'hot': ['for', 'for', 'BBs'],
#  'TV.”': ['Bitch,', 'I'],
#  'Bitch,': ['I', 'I'],
#  'does': ['not', 'music.', 'he', 'it', 'everybody', 'everybody'],
#  'sound': ['like', 'right?', 'will', 'like'],
#  'talk.': ['“Oh,'],
#  '“Oh,': ['that’s',
#   'yeah,',
#   'the',
#   'fantastic.',
#   'no!”',
#   'I',
#   'how',
#   'that',
#   'that',
#   'this',
#   'it'],
#  'would': ['never',
#   'smash',
#   'have',
#   'be',
#   'be.',
#   'be',
#   'there?',
#   'just',
#   'you',
#   'never',
#   'say.',
#   'be',
#   'say,'],
#  'guys': ['why', 'talking'],
#  'documentary.': ['It’s'],
#  'very': ['simple',
#   'important…',
#   'homophobic',
#   'controversial,',
#   'good',
#   'French…',
#   'famous',
#   'same',
#   'black.',
#   'few',
#   'soon.”',
#   'much,'],
#  'simple': ['reason,'],
#  'reason,': ['and,', 'uh,'],
#  'and,': ['uh,', 'I', 'for', 'hilariously,'],
#  'cannot': ['stress', 'host', 'say'],
#  'stress': ['this'],
#  'enough.': ['The'],
#  'reason': ['that'],
#  'because,': ['and'],
#  'important…': ['I'],
#  'all!': ['I'],
#  'anything!': ['I'],
#  'about.': ['I', 'I', 'Jussie'],
#  'hang': ['out'],
#  'Nothing.': ['So'],
#  'So': ['what', 'I', 'she', 'the', 'when', 'I'],
#  'for?': ['This'],
#  'guy,': ['R.'],
#  'Kelly,': ['got'],
#  'another': ['sex', 'idea', '12'],
#  'sex': ['tape', 'tapes', 'tapes.', 'tape.', 'tape.'],
#  'tape': ['out', 'like,'],
#  'Can': ['you', 'you', 'you', 'he', 'you', 'I'],
#  'tapes': ['than'],
#  'music.': ['He’s'],
#  'DJ': ['Khaled'],
#  'Khaled': ['of'],
#  'tapes.': ['“Another', 'The'],
#  '“Another': ['one.”'],
#  'one.”': ['Like,'],
#  'damn,': ['nigga!'],
#  'nigga!': ['That’s', 'Will'],
#  'lot': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'and'],
#  'bad': ['that', 'that', 'for', 'as', 'enough,'],
#  'this.': ['The', 'I', 'You', 'First', 'I'],
#  'prosecutor': ['in'],
#  'Chicago': ['came', 'late', 'and-and,', 'police'],
#  'came': ['out', 'on', 'on', 'home', 'out', 'out'],
#  'press': ['conference'],
#  'conference': ['and'],
#  'read': ['to', 'the', 'the', 'that'],
#  'media': ['a'],
#  'transcript': ['of'],
#  'tape.': ['Have', 'And'],
#  'Have': ['you', 'a', 'any', 'you'],
#  'heard': ['of', 'of', 'of', 'of.', 'of'],
#  'thing?': ['This', 'Kevin'],
#  'sounded': ['guilty'],
#  'guilty': ['in'],
#  'transcripts.': ['It’s'],
#  'amazing.': ['Sixteen'],
#  'Sixteen': ['times'],
#  'times': ['the', 'in'],
#  'girl’s': ['age'],
#  'age': ['was'],
#  'mentioned.': ['Isn’t'],
#  'Isn’t': ['that'],
#  'crazy?': ['This'],
#  'idiot.': ['He'],
#  'fuckin’': ['her',
#   'horror',
#   'guts.',
#   'gross.',
#   'tough',
#   'crazy.',
#   'crazy.',
#   'election',
#   'freezing',
#   'hate',
#   'live.'],
#  '“Yeah,': ['this', 'man,'],
#  '14-year-old': ['pussy', 'pussy?”'],
#  'pussy': ['I’ve', 'I’ve'],
#  '“You': ['like', 'need', 'shot', 'faggot'],
#  'pussy?”': ['Like,'],
#  'yeah,': ['I', 'we'],
#  'love': ['this.”', 'everybody.'],
#  'this.”': ['I’m'],
#  '“Man,': ['you'],
#  'need': ['to', 'to', 'some', 'to', 'to', 'to', '’em.', 'some', 'a', 'some'],
#  'shut': ['the', 'the', 'the', 'up,', 'the'],
#  'up.”': ['You'],
#  'give': ['your', 'me'],
#  'lawyer': ['something', 'can'],
#  'work': ['with.', 'really'],
#  'with.': ['You', 'So', 'It'],
#  'supposed': ['to', 'to', 'to', 'to', 'to', 'to'],
#  '“This': ['is', 'is', 'is'],
#  'best…': ['36-year-old'],
#  '36-year-old': ['pussy', 'pussy.'],
#  'Then': ['your', 'he'],
#  '“Your': ['Honor,'],
#  'Honor,': ['clearly'],
#  'clearly': ['my', 'lying.'],
#  'client': ['thought'],
#  '36,': ['as'],
#  'mentioned': ['some', 'anything'],
#  '16': ['times', 'degrees'],
#  'tape.”': ['They'],
#  'lying,': ['though,'],
#  'though,': ['you', 'I’d'],
#  'mean.': ['Everybody', 'I’m', 'Those'],
#  'Everybody': ['knows…', 'loves', 'likes', 'scream', 'in'],
#  'knows…': ['no'],
#  'pussy.': ['Doesn’t'],
#  'Doesn’t': ['matter', 'matter', 'that'],
#  'watching': ['this', 'the'],
#  'Netflix,': ['remember,'],
#  'remember,': ['bitch,', 'these', 'this', 'this', 'I'],
#  'clicked': ['on'],
#  'face.': ['Celebrity', '“Hey,', 'That’s', 'And'],
#  'Celebrity': ['hunting'],
#  'hunting': ['season.'],
#  'season.': ['Doesn’t'],
#  'say,': ['they’re', '“Hey,', 'not', 'like,', '“Wait', '“Hey,', '“Just'],
#  'they’re': ['going', 'calling', 'just', 'so'],
#  'everybody': ['eventually.', 'in', 'was', 'everything', 'at', 'have', 'have'],
#  'eventually.': ['Like,'],
#  'look,': ['I'],
#  'wrong,': ['but…', 'then'],
#  'but…': ['but'],
#  'we’ll': ['see.'],
#  'see.': ['They', 'And'],
#  'poor': ['Kevin',
#   'white',
#   'white',
#   'white',
#   'black',
#   'white',
#   'white',
#   'Dave'],
#  'Kevin': ['Hart.',
#   'Hart,',
#   'Hart’s',
#   'did,',
#   'became',
#   'Hart',
#   'is',
#   'had',
#   'said…',
#   'was',
#   'and',
#   'said,',
#   'fucked',
#   'had'],
#  'Hart.': ['Can'],
#  'imagine': ['such', 'if'],
#  'Hart,': ['let'],
#  'It': ['was…',
#   'was',
#   'was',
#   'all',
#   'happens',
#   'never',
#   'means,',
#   'scared',
#   'means',
#   'goes',
#   'hurts.',
#   'happens',
#   'sounds',
#   'was'],
#  'Hart’s': ['dream'],
#  'dream': ['to', 'for'],
#  'host': ['the', 'the', 'these'],
#  'Oscars.': ['That’s', 'And'],
#  'thinking': ['to', 'about'],
#  'myself,': ['“Well,', 'suddenly,', '“I'],
#  'awfully': ['strange'],
#  'strange': ['dream'],
#  'African': ['American.”', 'Americans.', 'American', 'Americans,', 'American'],
#  'American.”': ['What'],
#  'What': ['kind',
#   'is',
#   'if…',
#   'if',
#   'if…',
#   'if',
#   'if',
#   'does',
#   'is',
#   'the',
#   'the'],
#  'dreams': ['of'],
#  'hosting': ['the'],
#  'Oscars?': ['Kevin'],
#  'did,': ['that’s', 'nigga.'],
#  'who.': ['And'],
#  'Against': ['all'],
#  'odds,': ['Kevin'],
#  'became': ['the', 'famous'],
#  'most': ['famous', 'stringent'],
#  'famous': ['comedian', 'dad.', 'French', 'on'],
#  'comedian': ['this', 'Louis'],
#  'world': ['has', 'you’re'],
#  'seen,': ['and'],
#  'black': ['man', 'community', 'person'],
#  'had.': ['He'],
#  '80th': ['Oscars.'],
#  'Kevin,': ['but'],
#  'Hart': ['is'],
#  'damn': ['near'],
#  'near': ['perfect.'],
#  'As': ['close'],
#  'close': ['to'],
#  'anybody': ['I’ve', 'gonna', 'in'],
#  'seen.': ['In', 'All'],
#  'In': ['fact,', 'fact,'],
#  'fact,': ['Kevin', 'we', 'the', 'I'],
#  'precisely': ['four'],
#  'tweets': ['shy'],
#  'shy': ['of'],
#  'Ten': ['years'],
#  'made': ['some', 'because', 'the', 'a', 'fun', 'fun'],
#  'homophobic': ['comments.', 'attack.', 'for'],
#  'comments.': ['And'],
#  'repeat': ['what', 'the'],
#  'said…': ['because', 'that'],
#  'because': ['this', 'I’ve', 'he’s', 'we', 'I', 'I', 'I'],
#  'Atlanta.': ['You'],
#  'there’s': ['a', 'no', 'white', 'one', 'bird', 'six'],
#  'gay': ['men', 'community', 'friends.', 'community', 'or', 'community'],
#  'men': ['here', 'in', 'came', 'approached'],
#  'tonight…': ['with'],
#  'wives.': ['Far'],
#  'Far': ['be'],
#  'offend': ['anybody.'],
#  'anybody.': ['All'],
#  'are': ['not',
#   'great.”',
#   'not',
#   'never,',
#   'L’s.',
#   'B’s.',
#   'G’s.',
#   'their',
#   'driving',
#   'trying',
#   'just',
#   'the',
#   'fuckin’',
#   'making',
#   'a',
#   'you',
#   'actually',
#   'gonna',
#   'you',
#   'or',
#   'we',
#   'we',
#   'all',
#   'sick.',
#   'not',
#   'sick.',
#   'horribly',
#   'always',
#   'locked',
#   'not',
#   'broke.”',
#   'just',
#   'we',
#   'the',
#   'the'],
#  'words.': ['These', 'And', '“You'],
#  'These': ['were', 'white', 'people', 'are'],
#  'Kevin’s': ['words.'],
#  'ago.': ['And', 'It', 'I'],
#  'paraphrasing,': ['’cause'],
#  'other': ['people’s',
#   'line',
#   'shit,',
#   'kids.',
#   'crazy,',
#   'kids.',
#   'night',
#   'box'],
#  'jokes.': ['Okay,', '‘Cause', 'It’s'],
#  'son': ['was', 'saw'],
#  'demonstrating': ['or-or-or'],
#  'or-or-or': ['exhibiting,'],
#  'exhibiting,': ['uh,'],
#  'homosexual': ['behavior'],
#  'behavior': ['around'],
#  'house,': ['that', 'u-unless'],
#  'he’d': ['chastise'],
#  'chastise': ['him.'],
#  'He’d': ['say,'],
#  'gay.”': ['And', 'I'],
#  'smash': ['a'],
#  'dollhouse': ['over', 'over', 'to'],
#  'child’s': ['head.'],
#  'head.': ['Ooh,', '‘Cause,'],
#  'Ooh,': ['the'],
#  'community': ['was', 'was', 'must’ve', 'go', 'started', 'of'],
#  'furious.': ['And'],
#  'blame': ['’em.', '’em.'],
#  '’em.': ['I', 'But', 'It’s', 'It’s', 'It’s', 'Yeah,', 'Don’t'],
#  'friends.': ['And'],
#  'them,': ['100%', 'all'],
#  '100%': ['of'],
#  'horror': ['stories'],
#  'stories': ['about'],
#  'through': ['just', 'the', 'the', 'the'],
#  'themselves.': ['Crazy,', 'I’d', '“Hm…'],
#  'Crazy,': ['crazy'],
#  'crazy': ['stories.', 'to', 'story.'],
#  'stories.': ['And'],
#  'stories,': ['I'],
#  'them': ['has',
#   'L’s',
#   'B’s',
#   'G’s',
#   'that',
#   'booty',
#   'this',
#   'ducks?”',
#   'kids'],
#  'like…': ['their', '“I', '“Hey,', 'And', 'I', '“Well,', '“Why'],
#  'father': ['smashing'],
#  'smashing': ['a'],
#  '‘Cause,': ['clearly,'],
#  'clearly,': ['Kevin'],
#  'joking.': ['Think', 'This'],
#  'break': ['it'],
#  'head': ['in'],
#  'place.': ['Does'],
#  'Does': ['that', 'that'],
#  'Is': ['anybody', 'sexism'],
#  'upset,': ['and'],
#  'much': ['pressure', 'rope'],
#  'pressure': ['on'],
#  'Academy': ['of'],
#  'Motion': ['Pictures'],
#  'Pictures': ['and'],
#  'Sciences': ['that'],
#  '“If': ['you', 'you'],
#  'apologize': ['to'],
#  'community,': ['then'],
#  'Oscars.”': ['And'],
#  '“Fuck': ['it,'],
#  'quit.”': ['And'],
#  'every': ['talk', 'week.'],
#  'talk': ['show', 'a', 'about', 'like', 'about'],
#  'America': ['and'],
#  'apologized': ['for'],
#  'six': ['weeks.', 'shots'],
#  'weeks.': ['Kevin'],
#  'understand': ['the', 'me?”', 'is'],
#  'mistake': ['he', 'early'],
#  'same': ['mistake', 'car', 'day,'],
#  'early': ['in', 'from'],
#  'career.': ['This'],
#  'many': ['years'],
#  '15': ['years', 'years'],
#  'Show.': ['There’s'],
#  'a–': ['Thank'],
#  'Thank': ['you.', 'you.', 'you'],
#  'you.': ['Thank', 'On', 'I', 'I’ll', 'You', 'I'],
#  'On': ['network'],
#  'network': ['television,'],
#  'television,': ['they'],
#  'department': ['that’s', 'that'],
#  'called': ['Standards', 'Empire.', 'him'],
#  'Standards': ['and', 'and'],
#  'Practices.': ['This', 'They'],
#  'television.': ['And'],
#  'well,': ['you', 'then,', 'aren’t'],
#  'hear': ['from', 'from', 'all', 'your', 'somethin’.”'],
#  'making': ['Chappelle’s', 'the', 'that', 'that'],
#  'Show,': ['you’ll'],
#  'you’ll': ['hear', 'know'],
#  'time.': ['And', '“LBGT,', 'Feels'],
#  'mistake.': ['I'],
#  'done': ['anything'],
#  'wrong.': ['I', 'I', 'So,'],
#  'written': ['a'],
#  'sketch…': ['that'],
#  'word…': ['“faggot”', '“faggot”'],
#  '“faggot”': ['in', 'on'],
#  'call': ['me', 'the', 'this,'],
#  'calling': ['me,'],
#  'lady': ['that'],
#  'runs': ['the'],
#  'department.': ['She’s'],
#  'She’s': ['usually', 'like,'],
#  'usually': ['really'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Wife wakes me and I told me. I’d never forget… that I’m not funny? And if you’re proposing. And I.'
#
# >'Dude trespassing on a lot of us is different. I say. It’s mine. I don’t know what you just know.'

# %%
import random

def generate_sentence(chain, count=20):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(chapelle_dict)
# Out:
# 'Good. It’s… My mind’s telling jokes in their lives. But you decide to overcome one thing as they don’t know.'
